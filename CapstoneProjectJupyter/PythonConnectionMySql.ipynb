# %% [markdown]
# ## Installing mysql connector

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.1.0-cp310-cp310-win_amd64.whl.metadata (6.2 kB)
# Downloading mysql_connector_python-9.1.0-cp310-cp310-win_amd64.whl (16.1 MB)
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB 393.8 kB/s eta 0:00:41
#     --------------------------------------- 0.3/16.1 MB 2.1 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/16.1 MB 4.5 MB/s eta 0:00:04
#    --- ------------------------------------ 1.4/16.1 MB 6.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.0/16.1 MB 6.9 MB/s eta 0:00:03
#    ------ --------------------------------- 2.5/16.1 MB 7.6 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/16.1 MB 8.1 MB/s eta 0:00:02
#    -------- ------------------------------- 3.6/16.1 MB 8.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.1/16.1 MB 8.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/16.1 MB 9.1 MB/s eta 0:00:02
#    ------------- -------------------------- 5.3/16.1 MB 9.4 MB/s eta 0:00:02
#    -------------- ------------------------- 5.8/16.1 MB 9.6 MB/s eta 0:00:02
#    --------------- ------------------------ 6.4/16.1 MB 9.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.9/16.1 MB 9.8 MB/s eta 0:00:01
#    ------------------ --------------------- 7.4/16.1 MB 9.9 MB/s eta 0:00:01
#    ------------------- -------------------- 8.0/16.1 MB 10.0 MB/s eta 0:00:01
#    --------------------- ------------------ 8.5/16.1 MB 10.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.1/16.1 MB 10.2 MB/s eta 0:00:01
#    ------------------------ --------------- 9.6/16.1 MB 10.3 MB/s eta 0:00:01
#    ------------------------- -------------- 10.2/16.1 MB 10.4 MB/s eta 0:00:01
#    -------------------------- ------------- 10.7/16.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/16.1 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.8/16.1 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 12.4/16.1 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.9/16.1 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 13.5/16.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.0/16.1 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 14.6/16.1 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/16.1 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/16.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.1 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.1/16.1 MB 11.1 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.1.0

# %% [markdown]
# ### Import connector

# %%
import mysql.connector as connector

# %% [markdown]
# ### Establiching connection to the database

# %%
connection = connector.connect(user = "root", password = "*****")

# %%
import mysql.connector

#establishing the connection
conn = mysql.connector.connect(
   user='root', password='*****', host='127.0.0.1', database='littlelemondb'
)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()

# %%
show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)

# %%
for i in cursor:
    print(i)
# Out:
# ('address',)
# ('bookings',)
# ('customers',)
# ('menuitems',)
# ('menus',)
# ('orders',)
# ('orderstatus',)
# ('ordersview',)
# ('staff',)

# %% [markdown]
# ### Creating query

# %%
query_string = """
SELECT
			c.CustomerFullName,
            a.city,
            a.CountryCode,
            o.Cost
		FROM orders as o
        INNER JOIN customers as c ON c.CustomerID = o.CustomerID
        INNER JOIN address as a on c.AddressID = a.AddressID
        WHERE o.Cost > 60;
"""

# %%
cursor.execute(query_string)
result = cursor.fetchall()

# %%
for i in cursor:
    print(i)
# Out:
# ('Laney Fadden', 'Daruoyan', 'CN', Decimal('125.00'))
# ('Giacopo Bramich', 'Ongjin', 'KP', Decimal('235.00'))
# ('Lia Bonar', 'Quince Mil', 'PE', Decimal('75.00'))
# ('Merrill Baudon', 'Susaki', 'JP', Decimal('220.00'))
# ('Tasia Fautly', 'Tobruk', 'LY', Decimal('320.00'))
# ('Angel Veschambre', 'Rafael Hernandez Ochoa', 'MX', Decimal('210.00'))
# ('Sheilah Maestro', 'BelozÃ«rskoye', 'RU', Decimal('310.00'))
# ('Audie Willcocks', 'PÃ³voa do Valado', 'PT', Decimal('225.00'))
# ('Mart Malsher', 'Galâ€™bshtadt', 'RU', Decimal('190.00'))
# ('Magdalen Lacheze', 'Fuyang', 'CN', Decimal('98.00'))
# ('Margarita Mancktelow', 'Pindiga', 'NG', Decimal('168.27'))
# ('Ashil Brogini', 'Wakayama-shi', 'JP', Decimal('101.60'))
# ('Arthur Mathewson', 'Qingshan', 'CN', Decimal('93.13'))
# ('Tiffani Halstead', 'Chelbasskaya', 'RU', Decimal('91.84'))
# ('Roddie Winterbotham', 'Leticia', 'CO', Decimal('133.17'))
# ('Tony Crabtree', 'Kuzhu', 'CN', Decimal('83.99'))
# ('Tamarah Filasov', 'Kertamukti', 'ID', Decimal('69.38'))
# ('Pen Pruce', 'Yeghegnut', 'AM', Decimal('119.80'))
# ('Boot Burree', 'Baisangguan', 'CN', Decimal('125.00'))
# ('Sabra Calbreath', 'FrantiÅ¡kovy LÃ¡znÄ›', 'CZ', Decimal('235.00'))
# ('Obidiah Zanicchi', 'Tabu', 'ID', Decimal('75.00'))
# ('Anders Stowe', 'Daâ€™anshan', 'CN', Decimal('220.00'))
# ('Locke Janaway', 'Jelat', 'ID', Decimal('320.00'))
# ('Kaylyn Colebourne', 'Shuangqiao', 'CN', Decimal('210.00'))
# ('Noni Quickenden', 'Mont-Royal', 'CA', Decimal('310.00'))
# ('Alan Paskell', 'Longzui', 'CN', Decimal('225.00'))
# ('Anny Pattemore', 'Karanganyar', 'ID', Decimal('190.00'))
# ('Les Harmson', 'Podkamennaya Tunguska', 'RU', Decimal('98.00'))
# ('Horatio Lundy', 'Huangcun', 'CN', Decimal('168.27'))
# ('Sibley Rodder', 'Tyvriv', 'UA', Decimal('101.60'))
# ('Dniren Copperwaite', 'Zhuhu', 'CN', Decimal('93.13'))
# ('Alison Jamieson', 'CambuÃ\xad', 'BR', Decimal('91.84'))
# ('Dre Danher', 'Libei', 'CN', Decimal('133.17'))
# ('Adiana Shirtliff', 'Haradzyeya', 'BY', Decimal('83.99'))
# ('Derry Davis', 'La Loma', 'PA', Decimal('69.38'))
# ('Lenci McFadzean', 'El Triunfo de la Cruz', 'HN', Decimal('119.80'))
# ('Uriel Grooby', 'Izumi', 'JP', Decimal('125.00'))
# ('Jillayne Gaiford', 'BÅ«laevo', 'KZ', Decimal('235.00'))
# ('Tiertza Doogan', 'Ovsyanka', 'RU', Decimal('75.00'))
# ('Ilario Michie', 'Pindiga', 'NG', Decimal('220.00'))
# ('Sarah Plaschke', 'Narathiwat', 'TH', Decimal('320.00'))
# ('Skipp Lowater', 'Pacaraos', 'PE', Decimal('210.00'))
# ('Maddalena Wolfinger', 'Senanga', 'ZM', Decimal('310.00'))
# ('Mariquilla Labbe', 'NotsÃ©', 'TG', Decimal('225.00'))
# ('Cornelius Harkess', 'Morelos', 'MX', Decimal('190.00'))
# ('Erv Padrick', 'Phichai', 'TH', Decimal('98.00'))
# ('Fielding Struys', 'Shensuo', 'CN', Decimal('168.27'))
# ('Purcell Eyer', 'Qulsary', 'KZ', Decimal('124.62'))
# ('Pietra Dibdall', 'El Alamo', 'MX', Decimal('144.09'))
# ('Dyanne Labbet', 'Samanggen', 'ID', Decimal('101.60'))
# ('Elsworth Stannas', 'Jinhai', 'CN', Decimal('93.13'))
# ('Calvin Aucock', 'Ngarus', 'ID', Decimal('91.84'))
# ('Prudence Eastlake', 'Stockholm', 'SE', Decimal('133.17'))
# ('Jerrie Jiran', 'Lorena', 'BR', Decimal('83.99'))
# ('Linc Martynov', 'Saint-Malo', 'FR', Decimal('69.38'))
# ('Jackie Kment', 'Báº¿n Cáº§u', 'VN', Decimal('119.80'))
# ('Phil Schapero', 'Rancapare', 'ID', Decimal('125.00'))
# ('Giusto Sheavills', 'Mospyne', 'UA', Decimal('235.00'))
# ('Emmalynne Hairs', 'Lewobelek', 'ID', Decimal('75.00'))
# ('Mirna Rosita', 'Novorossiysk', 'RU', Decimal('220.00'))
# ('Alard Briat', 'Kyshtym', 'RU', Decimal('320.00'))
# ('Ferdinand Fowley', 'Ntungamo', 'UG', Decimal('210.00'))
# ('Averell Joint', 'Hancheng', 'CN', Decimal('310.00'))
# ('Deane Benbough', 'Dongxin', 'CN', Decimal('225.00'))
# ('Grenville Hyne', 'Shawan', 'CN', Decimal('190.00'))
# ('Asia McNess', 'Carromeu', 'PT', Decimal('98.00'))
# ('Fayre Crocket', 'Kohila', 'EE', Decimal('168.27'))
# ('Olive Jeannon', 'Kizhinga', 'RU', Decimal('124.62'))
# ('Karoline Pocock', 'Bislig', 'PH', Decimal('144.09'))
# ('Rosanne Zorzutti', 'Oji River', 'NG', Decimal('101.60'))
# ('Kele Bracknell', 'Pisangkemeng', 'ID', Decimal('93.13'))
# ('Marielle Buffey', 'Mogoditshane', 'BW', Decimal('91.84'))
# ('Maighdiln Lamswood', 'Guangshun', 'CN', Decimal('133.17'))
# ('Cirilo Koschek', 'GareÅ¡nica', 'HR', Decimal('83.99'))
# ('Konrad Standering', 'Sanshan', 'CN', Decimal('69.38'))
# ('Lilyan Schohier', 'Youchou', 'CN', Decimal('119.80'))
# ('Eva Dulake', 'Voiron', 'FR', Decimal('125.00'))
# ('Roi Critzen', 'Leninsk', 'RU', Decimal('235.00'))
# ('Darby McLae', 'Sinmak', 'KP', Decimal('75.00'))
# ('Christian Yeld', 'Parigi', 'ID', Decimal('220.00'))
# ('Delilah Ayerst', 'Ngedhusuba', 'ID', Decimal('320.00'))
# ('Hynda Skeel', 'Mata-Utu', 'WF', Decimal('210.00'))
# ('Mill Lambell', 'Otuzco', 'PE', Decimal('310.00'))
# ('Melicent Gieves', 'Jangkat', 'ID', Decimal('225.00'))
# ('Melisent Claessens', 'TÃ¢n PhÃº', 'VN', Decimal('190.00'))
# ('Son Hurworth', 'Cruz Alta', 'BR', Decimal('98.00'))
# ('Martainn Van Zon', 'Su-ngai Kolok', 'TH', Decimal('168.27'))
# ('Elladine Kobiela', 'Bajos de Haina', 'DO', Decimal('124.62'))
# ('Candy Simoncelli', 'Shuiting', 'CN', Decimal('144.09'))
# ('Berkley Petrashov', 'La Rioja', 'AR', Decimal('101.60'))
# ('Eba Harriagn', 'La Calera', 'AR', Decimal('93.13'))
# ('Kalindi Ryman', 'Sumbersari Wetan', 'ID', Decimal('91.84'))
# ('Viva Foulstone', 'OpatÃ³wek', 'PL', Decimal('133.17'))
# ('Evan Goldsbury', 'Businovo', 'RU', Decimal('83.99'))
# ('Linus Gresham', 'CaÃ±as', 'CR', Decimal('69.38'))
# ('Malchy Huddlestone', 'Hradec KrÃ¡lovÃ©', 'CZ', Decimal('119.80'))
# ('Hakeem Leadston', 'Haoxue', 'CN', Decimal('125.00'))
# ('Lucilia Sandeman', 'Liangjing', 'CN', Decimal('235.00'))
# ('Yorgos Staite', 'Hartswater', 'ZA', Decimal('75.00'))
# ('Lenore Tabb', 'Mayuan', 'CN', Decimal('220.00'))
# ('Cathleen Gooday', 'Sabugo', 'PT', Decimal('320.00'))
# ('Heinrick Setchfield', 'Yushikalasu', 'CN', Decimal('210.00'))
# ('Worth Laweles', 'Ho', 'GH', Decimal('310.00'))
# ('Noby Torvey', 'Couva', 'TT', Decimal('225.00'))
# ('Adah Adamczewski', 'Nangang', 'CN', Decimal('190.00'))
# ('Vivie Twinning', 'BanÄ« an NahÄ\x81rÄ«', 'YE', Decimal('98.00'))
# ('Zora Hanalan', 'Lagayan', 'PH', Decimal('168.27'))
# ('Ham Penhall', 'Kisoro', 'UG', Decimal('124.62'))
# ('Blancha Trippack', 'KassÃ¡ndreia', 'GR', Decimal('144.09'))
# ('Carney Speer', 'Duas Igrejas', 'PT', Decimal('101.60'))
# ('Christoforo Vagg', 'IjuÃ\xad', 'BR', Decimal('93.13'))
# ('Rana Rait', 'AÃ§ucena', 'BR', Decimal('91.84'))
# ('Nev Bompas', 'Qianyou', 'CN', Decimal('133.17'))
# ('Fredi Helks', 'Kasugai', 'JP', Decimal('83.99'))
# ('Steward Lavies', 'Parlilitan', 'ID', Decimal('69.38'))
# ('Anastasie Jahnisch', 'Biâ€™r al á¸¨ufayy', 'TN', Decimal('119.80'))
# ('Lyndel Rodwell', 'NÄ\x81lchiti', 'BD', Decimal('125.00'))
# ('Elisabetta Jacke', 'San Juan', 'PH', Decimal('235.00'))
# ('Gage Tocknell', 'Calasgasan', 'PH', Decimal('75.00'))
# ('Den Coppock.', 'Golden', 'CA', Decimal('220.00'))
# ('Granville Mallison', 'Longhuashan', 'CN', Decimal('320.00'))
# ('Davita Baynham', 'Osekovo', 'HR', Decimal('210.00'))
# ('Brook Rainger', 'Medaya', 'SY', Decimal('310.00'))
# ('Torr Windrus', 'Yejia', 'CN', Decimal('225.00'))
# ('Sterne Salterne', 'Shawnee Mission', 'US', Decimal('190.00'))
# ('Keane Wait', 'Emiliano Zapata', 'MX', Decimal('98.00'))
# ('Shelbi Grishakov', 'Makur', 'FM', Decimal('168.27'))
# ('Wyn Attwoull', 'LadhewÄ\x81la WarÄ\x81ich', 'PK', Decimal('124.62'))
# ('Mady McMennum', 'Provo', 'US', Decimal('144.09'))
# ('Hedi Pellington', 'Dranoc', 'XK', Decimal('101.60'))
# ('Durante Bullers', 'QuiÃ±ota', 'PE', Decimal('93.13'))
# ('Erika Greensmith', 'Kindu', 'CD', Decimal('91.84'))
# ('Gerta Sanday', 'Dengtang', 'CN', Decimal('133.17'))
# ('Alaric Thaw', 'Uppsala', 'SE', Decimal('83.99'))
# ('Ingamar Forker', 'Niedercorn', 'LU', Decimal('69.38'))
# ('Freida Nannizzi', 'Andrushivka', 'UA', Decimal('119.80'))
# ('Aurie Unthank', 'Buga', 'MN', Decimal('125.00'))
# ('Sayer Goudman', 'Juazeiro do Norte', 'BR', Decimal('235.00'))
# ('Ash Lodford', 'Yuejin', 'CN', Decimal('75.00'))
# ('Chaddy Mangeney', 'Zamora', 'HN', Decimal('220.00'))
# ('Cullie McBrady', 'Boavista', 'PT', Decimal('320.00'))
# ('Mack Fabri', 'Tarariras', 'UY', Decimal('210.00'))
# ('Christen Jedrachowicz', 'Bergville', 'ZA', Decimal('310.00'))
# ('Eleonore Stitcher', 'Nancheng', 'CN', Decimal('225.00'))
# ('Staci Coppens', 'Waiwukak', 'ID', Decimal('190.00'))
# ('Maible Dalgarno', 'Shuikou', 'CN', Decimal('98.00'))
# ('Viviyan Lantiff', 'Simod', 'PH', Decimal('168.27'))
# ('Gerta Hehir', 'Bel Air RiviÃ¨re SÃ¨che', 'MU', Decimal('124.62'))
# ('Lynsey Ludlamme', 'Luyang', 'CN', Decimal('144.09'))
# ('Kariotta Core', 'Kusheriki', 'NG', Decimal('101.60'))
# ('Carena Nucator', 'San Juan de Manapiare', 'VE', Decimal('93.13'))
# ('Kipp Coulling', 'Azenhas do Mar', 'PT', Decimal('91.84'))
# ('Alida Dumphy', 'Bagong Pagasa', 'PH', Decimal('133.17'))
# ('Ezequiel Cunniff', 'LubieÅ„ Kujawski', 'PL', Decimal('83.99'))
# ('Sully Cunney', 'Dowr-e RabÄ\x81Å£', 'AF', Decimal('69.38'))
# ('Clevey Garfit', 'Daegu', 'KR', Decimal('119.80'))
# ('Berne Banbury', 'Khuzhir', 'RU', Decimal('125.00'))
# ('Nessie Wheal', 'Gucheng', 'CN', Decimal('235.00'))
# ('Manolo Russ', 'Kroya', 'ID', Decimal('75.00'))
# ('Mureil Codman', 'Figueiredo', 'PT', Decimal('220.00'))
# ('Bradford Rafe', 'Koungheul', 'SN', Decimal('320.00'))
# ('Esra Mc Meekan', 'Heshan', 'CN', Decimal('210.00'))
# ('Web OHowbane', 'Igreja', 'PT', Decimal('310.00'))
# ('Jordan Donner', 'Vila Fria', 'PT', Decimal('225.00'))
# ('Yorgos BoHlingolsen', 'Figueira dos Cavaleiros', 'PT', Decimal('190.00'))
# ('Onfroi Kornyakov', 'Bongao', 'PH', Decimal('98.00'))
# ('Aubine Chardin', 'Pasian', 'PH', Decimal('168.27'))
# ('Hana Livesay', 'Wutong', 'CN', Decimal('124.62'))
# ('Cristabel Nutty', 'Yudaikelike', 'CN', Decimal('144.09'))
# ('Abigail Struis', 'Mahekou', 'CN', Decimal('101.60'))
# ('Cirillo Creamen', 'Yanghuxiang', 'CN', Decimal('93.13'))
# ('Tabbie Conboy', 'Corrientes', 'AR', Decimal('91.84'))
# ('Roth Cousans', 'Rijau', 'NG', Decimal('133.17'))
# ('Kally Biers', 'El JÃ\xadcaro', 'GT', Decimal('83.99'))
# ('Garek Gearty', 'Nara-shi', 'JP', Decimal('69.38'))
# ('Ulick Tebboth', 'Boguchar', 'RU', Decimal('119.80'))
# ('Merwin Pikhno', 'Reno', 'US', Decimal('125.00'))
# ('Silas Asson', 'Hupalivka', 'UA', Decimal('235.00'))
# ('Pierson Baal', 'Nansheng', 'CN', Decimal('75.00'))
# ('Reta Leipoldt', 'Cibangun Tengah', 'ID', Decimal('220.00'))
# ('Joline Cancelier', 'Saint-Claude', 'FR', Decimal('320.00'))
# ('Sheffield Turbitt', 'Motegi', 'JP', Decimal('210.00'))
# ('Giustina Thorne', 'Juá¸©r ad DÄ«k', 'PS', Decimal('310.00'))
# ('Gallagher Benyon', 'Hengli', 'CN', Decimal('225.00'))
# ('Sabra Corry', 'Takikawa', 'JP', Decimal('190.00'))
# ('Charline Windrus', 'Huangzhan', 'CN', Decimal('98.00'))
# ('Webster Lomax', 'Batelov', 'CZ', Decimal('168.27'))
# ('Vincent Boarer', 'Kastsyukovichy', 'BY', Decimal('124.62'))
# ('Dietrich Feetham', 'ManhiÃ§a', 'MZ', Decimal('144.09'))
# ('Charita Bosworth', 'Pisz', 'PL', Decimal('101.60'))
# ('Basil Slarke', 'Mamonovo', 'RU', Decimal('93.13'))
# ('Kali Avis', 'RodotÃ³pi', 'GR', Decimal('91.84'))
# ('Zebedee Spafford', 'Pasirmukti', 'ID', Decimal('133.17'))
# ('Lulu Hastin', 'Sandaoba', 'CN', Decimal('83.99'))
# ('Ardenia Lobb', 'Muzhijie', 'CN', Decimal('69.38'))
# ('Cissy Blondelle', 'Zhukovskiy', 'RU', Decimal('119.80'))
# ('Jill OSirin', 'Shiogama', 'JP', Decimal('125.00'))
# ('Tommi Durham', 'Kertorejo', 'ID', Decimal('235.00'))
# ('Adham Heyns', 'Bila Tserkva', 'UA', Decimal('75.00'))
# ('Shandeigh Andreas', 'Silveiros', 'PT', Decimal('220.00'))
# ('Ram Chaudhry', 'LÃ¼deritz', 'NA', Decimal('320.00'))
# ('Mattie Winyard', 'Baitian', 'CN', Decimal('210.00'))
# ('Forester Buxcey', 'BiguaÃ§u', 'BR', Decimal('310.00'))
# ('Crysta Garratty', 'Tambong', 'PH', Decimal('225.00'))
# ('Waylan Grieve', 'Lang', 'CN', Decimal('190.00'))
# ('Ermina Kitter', 'Dongzaogang', 'CN', Decimal('98.00'))
# ('Raymond Cranage', 'Tebluru', 'ID', Decimal('168.27'))
# ('Kore Smurfit', 'Gedangan', 'ID', Decimal('124.62'))
# ('Desdemona Dobbinson', 'Zaozerne', 'UA', Decimal('144.09'))
# ('Elora Eliesco', 'ChiÅŸinÄƒu', 'MD', Decimal('101.60'))
# ('Annaliese Cowill', 'Matagalpa', 'NI', Decimal('93.13'))
# ('Burgess Hancill', 'Mananjary', 'MG', Decimal('91.84'))
# ('Alvan Winspare', 'BayanaÅ«yl', 'KZ', Decimal('133.17'))
# ('Gilberta Sabberton', 'El RincÃ³n', 'PA', Decimal('83.99'))
# ('Reginauld Kelemen', 'Paris 01', 'FR', Decimal('69.38'))
# ('Merrill Sawford', 'Nggambel', 'ID', Decimal('119.80'))
# ('Jackelyn Jacox', 'Biga', 'PH', Decimal('125.00'))
# ('Rene Garn', 'Ngora', 'UG', Decimal('235.00'))
# ('Araldo Gutman', 'Gunziying', 'CN', Decimal('75.00'))
# ('Stewart Keppe', 'Salzburg', 'AT', Decimal('220.00'))
# ('Fidelity Banham', 'Thap Than', 'TH', Decimal('320.00'))
# ('Zorana Diggin', 'Baidian', 'CN', Decimal('210.00'))
# ('Grenville Bottomore', 'Siliana', 'TN', Decimal('310.00'))
# ('Julina Di Franceschi', 'Liangkou', 'CN', Decimal('225.00'))
# ('Natty Murt', 'Nyamanari', 'GM', Decimal('190.00'))
# ('Phillipe Ropartz', 'Lukunor', 'FM', Decimal('98.00'))
# ('Douglas O Cloney', 'Buracan', 'PH', Decimal('168.27'))
# ('Adrianne Freeland', 'Saint-Leu-la-ForÃªt', 'FR', Decimal('124.62'))
# ('Maisie Matyushkin', 'Zhenlong', 'CN', Decimal('144.09'))
# ('Lew Allot', 'Quinta da Courela', 'PT', Decimal('101.60'))
# ('Fairfax Seniour', 'Destrnik', 'SI', Decimal('93.13'))
# ('Aime Ferry', 'Sacramento', 'US', Decimal('91.84'))
# ('Waldo Tomkiss', 'Loivos', 'PT', Decimal('133.17'))
# ('Cate Pagitt', 'Cancas', 'PE', Decimal('83.99'))
# ('Johnette Haitlie', 'Biankouma', 'CI', Decimal('69.38'))
# ('Aldric Jerman', 'Longtian', 'CN', Decimal('119.80'))
# ('Maybelle Bellows', 'Viking', 'CA', Decimal('125.00'))
# ('Merlina Lermit', 'Allentown', 'US', Decimal('235.00'))
# ('Livvyy Grombridge', 'Aracruz', 'BR', Decimal('75.00'))
# ('Tibold MacGorley', 'Waiklibang', 'ID', Decimal('220.00'))
# ('Madelin Giacomi', 'Marmashen', 'AM', Decimal('320.00'))
# ('Arnie Jay', 'Ulimonong', 'ID', Decimal('210.00'))
# ('Berenice Marples', 'Krasnyy Luch', 'UA', Decimal('310.00'))
# ('Marys Offen', 'OberÃ¡', 'AR', Decimal('225.00'))
# ('Dacey Witherden', 'General JosÃ© de San MartÃ\xadn', 'AR', Decimal('190.00'))
# ('Chloette Pyke', 'Hexing', 'CN', Decimal('98.00'))
# ('Kameko Cockton', 'Bang Rak', 'TH', Decimal('168.27'))
# ('Rayner Lukianovich', 'Dampit', 'ID', Decimal('124.62'))
# ('Donella Tomasini', 'TromsÃ¸', 'NO', Decimal('144.09'))
# ('Dennison Qusklay', 'Mont-de-Marsan', 'FR', Decimal('101.60'))
# ('Orel Gawthrope', 'á¸¨awsh â€˜ÄªsÃ¡', 'EG', Decimal('93.13'))
# ('Mona Rudwell', 'Obiaruku Quarters', 'NG', Decimal('91.84'))
# ('Britta Barday', 'Mersam', 'ID', Decimal('133.17'))
# ('Phillis Denley', 'Lawonda', 'ID', Decimal('83.99'))
# ('Sandor Barradell', 'Cangkreng', 'ID', Decimal('69.38'))
# ('Rowena Santori', 'KÅ‚omnice', 'PL', Decimal('119.80'))
# ('Licha Verden', 'Manaus', 'BR', Decimal('125.00'))
# ('Anabelle Dominelli', 'KalÃ¡vryta', 'GR', Decimal('235.00'))
# ('Philomena Petracchi', 'Sosnovka', 'RU', Decimal('75.00'))
# ('Annaliese Brunsden', 'DÃ¼sseldorf', 'DE', Decimal('220.00'))
# ('Kym Lepard', 'Vales', 'PT', Decimal('320.00'))
# ('Haily Izakoff', 'Villiers', 'ZA', Decimal('210.00'))
# ('Junie Older', 'ShÄ«rvÄ\x81n', 'IR', Decimal('310.00'))
# ('Currie Fidell', 'Kasangulu', 'CD', Decimal('225.00'))
# ('Estele Schultze', 'Tisulâ€™', 'RU', Decimal('190.00'))
# ('Ber Dillet', 'Trinity Ville', 'JM', Decimal('98.00'))
# ('Merill Leyninye', 'Ustrzyki Dolne', 'PL', Decimal('168.27'))
# ('Herve Tunmore', 'Raffingora', 'ZW', Decimal('124.62'))
# ('Armstrong Collerd', 'Lallayug', 'PH', Decimal('144.09'))
# ('Allyce Mantione', 'Tosno', 'RU', Decimal('101.60'))
# ('Sue Voyce', 'Datong', 'CN', Decimal('93.13'))
# ('Dalila Baldree', 'Adamstown', 'PN', Decimal('91.84'))
# ('Becki Bonsall', 'Shanglaxiu', 'CN', Decimal('133.17'))
# ('Zach Bondley', 'Lampa', 'ID', Decimal('83.99'))
# ('Katherine Midson', 'TomaÅ¡evac', 'RS', Decimal('69.38'))
# ('Alisander Cornelisse', 'Prokhorovka', 'RU', Decimal('119.80'))
# ('Fax Rojahn', 'Fukiage-fujimi', 'JP', Decimal('125.00'))
# ('Hymie Meadowcroft', 'Arias', 'AR', Decimal('235.00'))
# ('Steffie Slemmonds', 'Sangba', 'CN', Decimal('75.00'))
# ('Melessa Lecordier', 'GradishtÃ«', 'AL', Decimal('220.00'))
# ('Gardy Neljes', 'Ihuari', 'PE', Decimal('320.00'))
# ('Chrotoem Estevez', 'Ayabaca', 'PE', Decimal('210.00'))
# ('Cori Percifer', 'El Limon', 'MX', Decimal('310.00'))
# ('Melisse Southeran', 'Pohrebyshche', 'UA', Decimal('225.00'))
# ('Maressa Fruish', 'WÄ\x81ling', 'NP', Decimal('190.00'))
# ('Moishe Constant', 'GrudÃ«-FushÃ«', 'AL', Decimal('98.00'))
# ('Jakie Bullan', 'TaboÃ£o da Serra', 'BR', Decimal('168.27'))
# ('Deloria Hannen', 'Alebtong', 'UG', Decimal('124.62'))
# ('Lucho McGerraghty', 'Dangbigih', 'ID', Decimal('144.09'))
# ('Dwain Eccott', 'Kallar KahÄ\x81r', 'PK', Decimal('101.60'))
# ('Jerome Ovitts', 'Guanagazapa', 'GT', Decimal('93.13'))
# ('Essy Licence', 'Toledo', 'PH', Decimal('91.84'))
# ('Rosaleen Ionnisian', 'QÅ\xadrghontepa', 'UZ', Decimal('133.17'))
# ('Sullivan Eddoes', 'Barqueiro', 'PT', Decimal('83.99'))
# ('Flem Haibel', 'Koesan', 'KR', Decimal('69.38'))
# ('Gualterio Backshall', 'TelÃªmaco Borba', 'BR', Decimal('119.80'))
# ('Chauncey Barrott', 'Langpas', 'PH', Decimal('125.00'))
# ('Lana Boyne', 'Jinshi', 'CN', Decimal('235.00'))
# ('Mickie Alred', 'Inashiki', 'JP', Decimal('75.00'))
# ('Kellyann Sambells', 'Brongkalan', 'ID', Decimal('220.00'))
# ('Alexia Candelin', 'Vihti', 'FI', Decimal('320.00'))
# ('Bianka McLanaghan', 'Sangkulirang', 'ID', Decimal('210.00'))
# ('Pansie Alldis', 'ZÅ‚otniki', 'PL', Decimal('310.00'))
# ('Olly Dobbinson', 'LukovÃ«', 'AL', Decimal('225.00'))
# ('Hale Danilchik', 'Kaducondong', 'ID', Decimal('190.00'))
# ('Sandy Rubinowicz', 'Guilin', 'CN', Decimal('98.00'))
# ('Lucais Sewards', 'Meishan', 'CN', Decimal('168.27'))
# ('Joye MacHostie', 'Novoye Leushino', 'RU', Decimal('124.62'))
# ('Celinda Mamwell', 'Lela', 'ID', Decimal('144.09'))
# ('Norby Foord', 'KoryÄ\x8dany', 'CZ', Decimal('101.60'))
# ('Malinde Blunn', 'Dusun Tengah Cihaurbeuti', 'ID', Decimal('93.13'))
# ('Rafferty Guyonneau', 'Santa Magdalena', 'PH', Decimal('91.84'))
# ('Marice Leavens', 'Zhongxin', 'CN', Decimal('133.17'))
# ('Brook Begent', 'IkÅ¡Ä·ile', 'LV', Decimal('83.99'))
# ('Ario Meekin', 'Longju', 'CN', Decimal('69.38'))
# ('Schuyler Walewski', 'Inglewood', 'US', Decimal('119.80'))
# ('Ariadne Copeland', 'Phoenix', 'US', Decimal('125.00'))
# ('Tamma Clink', 'Charlotte', 'US', Decimal('235.00'))
# ('Jaynell Alty', 'Delta del Tigre', 'UY', Decimal('75.00'))
# ('Laurianne Diehn', 'Ikongo', 'MG', Decimal('220.00'))
# ('Padraic Zanutti', 'Svojat', 'BA', Decimal('320.00'))
# ('Codee Pindar', 'DrosiÃ¡', 'GR', Decimal('210.00'))
# ('Gabey Macewan', 'Tagnanan', 'PH', Decimal('310.00'))
# ('Dinny Fonzone', 'Mojogajeh', 'ID', Decimal('225.00'))
# ('Adamo Rumens', 'BodÄ\xad', 'MN', Decimal('190.00'))
# ('Lottie Schultheiss', 'Miharu', 'JP', Decimal('98.00'))
# ('Ferguson Wilcocke', 'SychÃ«vo', 'RU', Decimal('168.27'))
# ('Kelwin Ryle', 'Pidigan', 'PH', Decimal('124.62'))
# ('Griz Tawse', 'Bangkalan', 'ID', Decimal('144.09'))
# ('Katie Betancourt', 'Bender', 'MD', Decimal('101.60'))
# ('Caterina Sweetnam', 'Babatngon', 'PH', Decimal('93.13'))
# ('Durand Kitt', 'Aban', 'RU', Decimal('91.84'))
# ('Veradis Tiddy', 'Stepnica', 'PL', Decimal('133.17'))
# ('Barnabas Gerrell', 'Mompach', 'LU', Decimal('83.99'))
# ('Hinda Giacopetti', 'Saint-Avold', 'FR', Decimal('69.38'))
# ('Zolly Heinzel', 'Kaliska', 'PL', Decimal('119.80'))
# ('Julianna Jostan', 'Agusan', 'PH', Decimal('125.00'))
# ('Hallie Roddam', 'Setono', 'ID', Decimal('235.00'))
# ('Madlin McGrory', 'Shangcai Zhongxing', 'CN', Decimal('75.00'))
# ('Tersina Wolfer', 'Shiraz', 'IR', Decimal('220.00'))
# ('Andonis Rawling', 'Shengrenjian', 'CN', Decimal('320.00'))
# ('Aluin McUre', 'GrÃ¥bo', 'SE', Decimal('210.00'))
# ('Damiano Yurasov', 'Dampol', 'PH', Decimal('310.00'))
# ('Almeta Laird-Craig', 'Karukh', 'AF', Decimal('225.00'))
# ('Nickolai Balmer', 'Huolianpo', 'CN', Decimal('190.00'))
# ('Isac Crimpe', 'Ã‰vreux', 'FR', Decimal('98.00'))
# ('Verene Beatens', 'Lamas', 'PT', Decimal('168.27'))
# ('Carol-jean Croston', 'Sijing', 'CN', Decimal('124.62'))
# ('Dareen Soutar', 'MukÅ\x8d', 'JP', Decimal('144.09'))
# ('Pietra Paute', 'San Antonio', 'PE', Decimal('101.60'))
# ('Evvie Crossby', 'Ouango', 'CF', Decimal('93.13'))
# ('Dennie Lilloe', 'Yueyang', 'CN', Decimal('91.84'))
# ('Orelle Beadel', 'Lingquan', 'CN', Decimal('133.17'))
# ('Pete Morden', 'Caidian', 'CN', Decimal('83.99'))
# ('Margarette Hobell', 'Moville', 'IE', Decimal('69.38'))
# ('Ansell Lethlay', 'Morrelgonj', 'BD', Decimal('119.80'))
# ('Kathy Fairlam', 'Shilong', 'CN', Decimal('125.00'))
# ('Cleon Moreton', 'Youcheng', 'CN', Decimal('235.00'))
# ('Allyce Berthon', 'Vitim', 'RU', Decimal('75.00'))
# ('Garvin Guerrazzi', 'Baiyun', 'CN', Decimal('220.00'))
# ('Susette ONeil', 'Hamilton', 'US', Decimal('320.00'))
# ('Ignace Cooney', 'Chapultepec', 'MX', Decimal('210.00'))
# ('Emera Whitewood', 'Manta', 'EC', Decimal('310.00'))
# ('Miquela Dutnell', 'Kamenskiy', 'RU', Decimal('225.00'))
# ('Montgomery Spileman', 'Tselinnoye', 'RU', Decimal('190.00'))
# ('Salem Morgen', 'Zhengcun', 'CN', Decimal('98.00'))
# ('Enid Francescuccio', 'MoglicÃ«', 'AL', Decimal('168.27'))
# ('Evelyn Serrier', 'Lorient', 'FR', Decimal('124.62'))
# ('Virginie McGrey', 'Kuala Lumpur', 'MY', Decimal('144.09'))
# ('Susie Torrisi', 'Yazykovo', 'RU', Decimal('101.60'))
# ('Georgeanna Boulton', 'Mayskiy', 'RU', Decimal('93.13'))
# ('Spenser Wandless', 'Qinxi', 'CN', Decimal('91.84'))
# ('Ethelind Schnieder', 'Kinna', 'SE', Decimal('133.17'))
# ('Laverna Skeermer', 'Nankengzi', 'CN', Decimal('83.99'))
# ('Granger Aiers', 'Spytkowice', 'PL', Decimal('69.38'))
# ('Lilian Dislee', 'CordeirÃ³polis', 'BR', Decimal('119.80'))
# ('Chrotoem Harniman', 'Petauke', 'ZM', Decimal('125.00'))
# ('Thorny Westrip', 'LidorÃ\xadki', 'GR', Decimal('235.00'))
# ('Berny Elcoate', 'PalpalÃ¡', 'AR', Decimal('75.00'))
# ('Kiersten Dalliwater', 'Saumur', 'FR', Decimal('220.00'))
# ('Ives Armstead', 'Nobo', 'ID', Decimal('320.00'))
# ('Hersh Bolgar', 'Cheongsong gun', 'KR', Decimal('210.00'))
# ('Carlin Brabon', 'Mocajuba', 'BR', Decimal('310.00'))
# ('Mignonne Shepland', 'Sudo', 'ID', Decimal('225.00'))
# ('Jacky Shapero', 'Hamilton', 'BM', Decimal('190.00'))
# ('Roch Panchen', 'Belo Jardim', 'BR', Decimal('98.00'))
# ('Stan Clethro', 'Samashki', 'RU', Decimal('168.27'))
# ('Hamlen Mashro', 'Hexi', 'CN', Decimal('124.62'))
# ('Marena Jacox', 'Montauban', 'FR', Decimal('144.09'))
# ('Lorna Bogart', 'Novoderevyankovskaya', 'RU', Decimal('101.60'))
# ('Mirilla Barff', 'Chenyangzhai', 'CN', Decimal('93.13'))
# ('Weston Dearden', 'Fenhe', 'CN', Decimal('91.84'))
# ('Kimble Wayvill', 'Sankwia', 'GM', Decimal('133.17'))
# ('Alexandros Brookfield', 'Tiancheng', 'CN', Decimal('83.99'))
# ('Katrina Aylett', 'Lyon', 'FR', Decimal('69.38'))
# ('Mateo Wightman', 'Topolâ€™noye', 'RU', Decimal('119.80'))
# ('Ariadne McCrie', 'Baing', 'ID', Decimal('125.00'))
# ('Karlene Whetson', 'NiafunkÃ©', 'ML', Decimal('235.00'))
# ('Camille Symmons', 'Zhangfeng', 'CN', Decimal('75.00'))
# ('Silva Addy', 'Vyksa', 'RU', Decimal('220.00'))
# ('Maddie Raw', 'Leshukonskoye', 'RU', Decimal('320.00'))
# ('Marcile Meffen', 'Nanping', 'CN', Decimal('210.00'))
# ('Elliott Avard', 'ZabruÅ¡any', 'CZ', Decimal('310.00'))
# ('Cyndi Ruler', 'Smokvica', 'HR', Decimal('225.00'))
# ('Lauralee Beteriss', 'Kungsbacka', 'SE', Decimal('190.00'))
# ('Beth Crocket', 'Hita', 'JP', Decimal('98.00'))
# ('Peggie Biddles', 'Melaka', 'MY', Decimal('168.27'))
# ('Roxana Dicte', 'Guadalupe', 'MX', Decimal('124.62'))
# ('Alyse Pimlett', 'Rzeczenica', 'PL', Decimal('144.09'))
# ('Jolee Linthead', 'Pekalongan', 'ID', Decimal('101.60'))
# ('Brit Northfield', 'Sumberejo', 'ID', Decimal('93.13'))
# ('Araldo Bramhall', 'Markham', 'CA', Decimal('91.84'))
# ('Josiah Thayre', 'Cantilan', 'PH', Decimal('133.17'))
# ('Trixy Southwick', 'KlenÄ\x8dÃ\xad pod ÄŒerchovem', 'CZ', Decimal('83.99'))
# ('Callie Dunning', 'Jiaotan', 'CN', Decimal('69.38'))
# ('Melloney Schimke', 'GalÃ¡n', 'CO', Decimal('119.80'))
# ('Tammara Burgyn', 'WohyÅ„', 'PL', Decimal('125.00'))
# ('Seamus Hearl', 'Kokhanava', 'BY', Decimal('235.00'))
# ('Yorgo Muzzillo', 'Gunungbatu', 'ID', Decimal('75.00'))
# ('Tiler Kenrack', 'Olds', 'CA', Decimal('220.00'))
# ('Shannon Osban', 'Dapuchaihe', 'CN', Decimal('320.00'))
# ('Forest Cole', 'Palencia', 'GT', Decimal('210.00'))
# ('Fred Tatersale', 'Lintaca', 'BO', Decimal('310.00'))
# ('Salvidor Francesch', 'Huangzhawan', 'CN', Decimal('225.00'))
# ('Sharai MacMenamin', 'Velâ€™sk', 'RU', Decimal('190.00'))
# ('Reuben Iannello', 'Hallstahammar', 'SE', Decimal('98.00'))
# ('Ginevra Pally', 'Saint-Denis', 'RE', Decimal('168.27'))
# ('Annice Maxworthy', 'Pujijie', 'CN', Decimal('124.62'))
# ('Koo Vinick', 'OstrzeszÃ³w', 'PL', Decimal('144.09'))
# ('Hilly Leahey', 'Yanghu', 'CN', Decimal('101.60'))
# ('Hilary Pudner', 'Pangal Sur', 'PH', Decimal('93.13'))
# ('Danyelle Butts', 'Baojiadian', 'CN', Decimal('91.84'))
# ('Rowan Grover', 'Palmira', 'CO', Decimal('133.17'))
# ('Renard Crispin', 'SÃ£o Martinho de Ã\x81rvore', 'PT', Decimal('83.99'))
# ('Tatiania OCrigane', 'Semenivka', 'UA', Decimal('69.38'))
# ('Koral Stampfer', 'Jijiang', 'CN', Decimal('119.80'))
# ('Launce Sowerbutts', 'Tan-Tan', 'MA', Decimal('125.00'))
# ('Leone Klulisek', 'Dodoma', 'TZ', Decimal('235.00'))
# ('Maison Shoreson', 'Guadalupe', 'PA', Decimal('75.00'))
# ('Tricia Bellsham', 'Mene de Mauroa', 'VE', Decimal('220.00'))
# ('Amye Limbert', 'Hpa-an', 'MM', Decimal('320.00'))
# ('Igor Durrand', 'Hebei', 'CN', Decimal('210.00'))
# ('Everard Trasler', 'Kut Chap', 'TH', Decimal('310.00'))
# ('Chastity Medlar', 'Girijaya', 'ID', Decimal('225.00'))
# ('Morgan Gouldeby', 'Jequitinhonha', 'BR', Decimal('190.00'))
# ('Read Trusty', 'Chumphon', 'TH', Decimal('98.00'))
# ('Flynn Magnay', 'Jasienica', 'PL', Decimal('168.27'))
# ('Kiley Nare', 'Canutama', 'BR', Decimal('124.62'))
# ('Elfrieda Umbers', 'Novyye Gorki', 'RU', Decimal('144.09'))
# ('Tera Stockdale', 'Cholet', 'FR', Decimal('101.60'))
# ('Bree Bleas', 'Fenkeng', 'CN', Decimal('93.13'))
# ('Haskel Bowell', 'Qiaodong', 'CN', Decimal('91.84'))
# ('Julius Scutchin', 'Buenavista', 'PH', Decimal('133.17'))
# ('Petronille Southwood', 'Figueira', 'PT', Decimal('83.99'))
# ('Paulie Lemerle', 'Fandriana', 'MG', Decimal('69.38'))
# ('Rhody Dobbin', 'Danao', 'PH', Decimal('119.80'))
# ('Rene Clements', 'Cliza', 'BO', Decimal('125.00'))
# ('Agnes Acey', 'Sasnovy Bor', 'BY', Decimal('235.00'))
# ('Verena Garman', 'Kauhan', 'ID', Decimal('75.00'))
# ('Claire Morland', 'Santiago de Cuba', 'CU', Decimal('220.00'))
# ('Othella Flood', 'Thap Than', 'TH', Decimal('320.00'))
# ('Nertie Igglesden', 'Elx/Elche', 'ES', Decimal('210.00'))
# ('Linus Greer', 'Alah SÄ\x81y', 'AF', Decimal('310.00'))
# ('Des Covet', 'NurmijÃ¤rvi', 'FI', Decimal('225.00'))
# ('Jacynth Clubb', 'BÄ™czarka', 'PL', Decimal('190.00'))
# ('Payton Rissen', 'Panitan', 'PH', Decimal('98.00'))
# ('Coralie Keenlayside', 'Mulandoro', 'ID', Decimal('168.27'))
# ('Alli Cunney', 'Hongtang', 'CN', Decimal('124.62'))
# ('Ulberto Alyutin', 'Piritiba', 'BR', Decimal('144.09'))
# ('Sinclare Milburne', 'VÃ¡ri', 'GR', Decimal('101.60'))
# ('Devy Hookes', 'Tanzhou', 'CN', Decimal('93.13'))
# ('Kalinda Grestye', 'Chadian', 'CN', Decimal('91.84'))
# ('Robbin Shottin', 'Yangyong', 'CN', Decimal('133.17'))
# ('Jemmy Whelan', 'Conde', 'BR', Decimal('83.99'))
# ('Gearard Rowston', 'Sneek', 'NL', Decimal('69.38'))
# ('Kenna Lideard', 'Claremont', 'ZA', Decimal('119.80'))
# ('Doll Friary', 'Novouzensk', 'RU', Decimal('125.00'))
# ('Gualterio Paget', 'Dos Quebradas', 'CO', Decimal('235.00'))
# ('Serena Yerby', 'BrÃ©tigny-sur-Orge', 'FR', Decimal('75.00'))
# ('Nita Vannacci', 'ShÄ\x81zand', 'IR', Decimal('220.00'))
# ('Henry Reaney', 'Limoeiro de Anadia', 'BR', Decimal('320.00'))
# ('Rooney Milbourne', 'Vilnius', 'LT', Decimal('210.00'))
# ('Marketa Olman', 'Cilimus Kulon', 'ID', Decimal('310.00'))
# ('Klement Brothwell', 'MaÃ±azo', 'PE', Decimal('225.00'))
# ('Andrej Wolfindale', 'Tawala', 'PH', Decimal('190.00'))
# ('Rudolph Brozek', 'Paris 18', 'FR', Decimal('98.00'))
# ('Ryley McKillop', 'Huai Mek', 'TH', Decimal('168.27'))
# ('Riley Curnnok', 'Saint Helier', 'JE', Decimal('124.62'))
# ('Galina Whaites', 'Qiaozi', 'CN', Decimal('144.09'))
# ('Rania Gerritsma', 'Macheke', 'ZW', Decimal('101.60'))
# ('Evangeline Bernet', 'Gaoping', 'CN', Decimal('93.13'))
# ('Cathe Snar', 'Yangyong', 'CN', Decimal('91.84'))
# ('Terry Iannitti', 'Outeiro', 'PT', Decimal('133.17'))
# ('Debbi Gaule', 'Le Raincy', 'FR', Decimal('83.99'))
# ('Xymenes Hands', 'Silvares', 'PT', Decimal('69.38'))
# ('Killy Condie', 'Fershampenuaz', 'RU', Decimal('119.80'))
# ('Elke Dumingos', 'Pingshan', 'CN', Decimal('125.00'))
# ('Dusty Yedall', 'Wilkes Barre', 'US', Decimal('235.00'))
# ('Marchelle Annes', 'Rozhniv', 'UA', Decimal('75.00'))
# ('Riordan Wormald', 'Felege Neway', 'ET', Decimal('220.00'))
# ('Dodi Lenglet', 'Longhua', 'CN', Decimal('320.00'))
# ('Calla Lambal', 'AreguÃ¡', 'PY', Decimal('210.00'))
# ('Josephine Archer', 'Zhuangbian', 'CN', Decimal('310.00'))
# ('Henryetta Kunes', 'Leiden', 'NL', Decimal('225.00'))
# ('Gusella Wadeling', 'Ciampea', 'ID', Decimal('190.00'))
# ('Ag Gasking', 'MontbÃ©liard', 'FR', Decimal('98.00'))
# ('Filmer Floyd', 'Loma Bonita', 'MX', Decimal('168.27'))
# ('Amandi McConaghy', 'Skhira', 'TN', Decimal('124.62'))
# ('Maryellen Gligori', 'MechrÃ¡ Belqsiri', 'MA', Decimal('144.09'))
# ('Sibyl Cuphus', 'La Jicaral', 'NI', Decimal('101.60'))
# ('Mathew Groucutt', 'Ete', 'NG', Decimal('93.13'))
# ('Pauline Danihelka', 'Tomingad', 'PH', Decimal('91.84'))
# ('Carleen Gyver', 'Spandaryan', 'AM', Decimal('133.17'))
# ('Polly Murton', 'Bontoc', 'PH', Decimal('83.99'))
# ('Cecilia Swinbourne', 'Refojos', 'PT', Decimal('69.38'))
# ('Felix Ouver', 'OpaÅ™any', 'CZ', Decimal('119.80'))
# ('Wynnie Feronet', 'Dongxin', 'CN', Decimal('125.00'))
# ('Enriqueta Kirwin', 'Valtimo', 'FI', Decimal('235.00'))
# ('Cathee Briscam', 'Stuttgart', 'DE', Decimal('75.00'))
# ('Lauri Hughill', 'Banjar Kelodan', 'ID', Decimal('220.00'))
# ('Meg Reburn', 'Yongchang', 'CN', Decimal('320.00'))
# ('Roanna Safont', 'Kansas City', 'US', Decimal('210.00'))
# ('Nerty Green', 'Fenjie', 'CN', Decimal('310.00'))
# ('Natasha Cool', 'Eindhoven', 'NL', Decimal('225.00'))
# ('Cyril Copelli', 'Abang', 'ID', Decimal('190.00'))
# ('Stormi Duddin', 'Queenstown', 'ZA', Decimal('98.00'))
# ('Alberik Rowcastle', 'Kiambu', 'KE', Decimal('168.27'))
# ('Deck Paulat', 'Couto', 'PT', Decimal('124.62'))
# ('Richie Brydson', 'Chesapeake', 'US', Decimal('144.09'))
# ('Audra Hebborn', 'Luti', 'ID', Decimal('101.60'))
# ('Melita Drinkale', 'Shijiao', 'CN', Decimal('93.13'))
# ('Elisabetta Dubery', 'Beira', 'MZ', Decimal('91.84'))
# ('Del Hughman', 'Zhongbao', 'CN', Decimal('133.17'))
# ('Karel Welband', 'NovÃ¡ Role', 'CZ', Decimal('83.99'))
# ('Ondrea Keyser', 'LijeÅ¡nica', 'BA', Decimal('69.38'))
# ('Liam Downing', 'Bunawan', 'PH', Decimal('119.80'))
# ('Ezequiel Benion', 'Trinity Ville', 'JM', Decimal('125.00'))
# ('Willa Wethered', 'Hang Dong', 'TH', Decimal('235.00'))
# ('Devland Pagett', 'Dubrovka', 'RU', Decimal('75.00'))
# ('Beryl Coo', 'Santa MarÃ\xada de Ipire', 'VE', Decimal('220.00'))
# ('Nels Ordish', 'Sapouy', 'BF', Decimal('320.00'))
# ('Curry Able', 'Singkir', 'ID', Decimal('210.00'))
# ('Lind Haggath', 'Comallo', 'AR', Decimal('310.00'))
# ('Red Nordass', 'Kalepasan', 'ID', Decimal('225.00'))
# ('Hamnet Coultas', 'Katori-shi', 'JP', Decimal('190.00'))
# ('Kelsy Schroder', 'Gersikputih Tengah', 'ID', Decimal('98.00'))
# ('Adelheid Casolla', 'Sarae', 'ID', Decimal('168.27'))
# ('Jesse Martelet', 'Shilovo', 'RU', Decimal('124.62'))
# ('Cornela LaBastida', 'Longsheng', 'CN', Decimal('144.09'))
# ('Ximenez Meredith', 'YÃ©limanÃ©', 'ML', Decimal('101.60'))
# ('Sherm Probat', 'Krasnopillya', 'UA', Decimal('93.13'))
# ('Thorin Jolliman', 'Shuangfeng', 'CN', Decimal('91.84'))
# ('Alfreda Chasmer', 'Fort Smith', 'US', Decimal('133.17'))
# ('Nels Hargreaves', 'Houk', 'FM', Decimal('83.99'))
# ('Stephanie Uman', 'HiratachÅ\x8d', 'JP', Decimal('69.38'))
# ('Leonie Battin', 'Pionerskiy', 'RU', Decimal('119.80'))
# ('Leslie Noden', 'Carbajales', 'HN', Decimal('125.00'))
# ('Grenville Penburton', 'Zhaoyuan', 'CN', Decimal('235.00'))
# ('Celle Oller', 'VÃ¥rgÃ¥rda', 'SE', Decimal('75.00'))
# ('Ibrahim Jurries', 'Vilar', 'PT', Decimal('220.00'))
# ('Renato Paulin', 'Grand Junction', 'US', Decimal('320.00'))
# ('Janeva Silman', 'Birmingham', 'US', Decimal('210.00'))
# ('Pablo Dracksford', 'Rio Claro', 'TT', Decimal('310.00'))
# ('Erinn Vannar', 'Villeneuve-lÃ¨s-Avignon', 'FR', Decimal('225.00'))
# ('Amandie Rohmer', 'Aloja', 'LV', Decimal('190.00'))
# ('Gordan Hitscher', 'Basiong', 'ID', Decimal('98.00'))
# ('Emelda Furbank', 'Inyati', 'ZW', Decimal('168.27'))
# ('Marsh Fransoni', 'Krasnaya Poyma', 'RU', Decimal('124.62'))
# ('Law Leinweber', 'Wonorejo', 'ID', Decimal('144.09'))
# ('Kaleena Philips', 'Pandaan', 'ID', Decimal('101.60'))
# ('Eyde Ellerton', 'Porto Formoso', 'PT', Decimal('93.13'))
# ('Itch Merle', 'Ja Ela', 'LK', Decimal('91.84'))
# ('Henrie Ledward', 'Arias', 'AR', Decimal('133.17'))
# ('Jessalin Dimitriades', 'Sampir', 'ID', Decimal('83.99'))
# ('Burke Jupp', 'Kupavna', 'RU', Decimal('69.38'))
# ('Farrel Teare', 'GosÃ« e Madhe', 'AL', Decimal('119.80'))
# ('Saul Parsonage', 'Gudang', 'ID', Decimal('125.00'))
# ('Sharon Lazare', 'Ayacucho', 'PE', Decimal('235.00'))
# ('Ainslee Feighney', 'Itapissuma', 'BR', Decimal('75.00'))
# ('Jessey Doddrell', 'Log pri Brezovici', 'SI', Decimal('220.00'))
# ('Marsiella Duprey', 'ÅŒbu', 'JP', Decimal('320.00'))
# ('Gianni Aistrop', 'San Francisco', 'CO', Decimal('210.00'))
# ('Neely Frankcomb', 'Xiaogang', 'CN', Decimal('310.00'))
# ('Lucretia Whyborn', 'Pilluana', 'PE', Decimal('225.00'))
# ('Alister Stronack', 'Kudang', 'ID', Decimal('190.00'))
# ('Nancy Rollinshaw', 'Smoky Lake', 'CA', Decimal('98.00'))
# ('Eimile Matz', 'Malunda', 'ID', Decimal('168.27'))
# ('Valerye Phorsby', 'Cipari Satu', 'ID', Decimal('124.62'))
# ('Gothart Domesday', 'Sokhumi', 'GE', Decimal('144.09'))
# ('Ram Sinclaire', 'PriozÃ«rsk', 'RU', Decimal('101.60'))
# ('Henrie Karolovsky', 'Karpogory', 'RU', Decimal('93.13'))
# ('Reg Lepper', 'Koua', 'KM', Decimal('91.84'))
# ('Wenona MacGinlay', 'Chicago', 'US', Decimal('133.17'))
# ('Cele Dunster', 'Tomakivka', 'UA', Decimal('83.99'))
# ('Jenn Josephoff', 'Garmeh', 'IR', Decimal('69.38'))
# ('Tyson Gahagan', 'Kota Bharu', 'MY', Decimal('119.80'))
# ('Felice Fiddler', 'Novyy Starodub', 'UA', Decimal('125.00'))
# ('Charline Warriner', 'Skara', 'SE', Decimal('235.00'))
# ('Hanni Dunbleton', 'Dalubian', 'CN', Decimal('75.00'))
# ('Terrye Littlechild', 'Gangbian', 'CN', Decimal('220.00'))
# ('Anjela Shobrook', 'Berbera', 'SO', Decimal('320.00'))
# ('Steven Cornbell', 'SzÃ©kesfehÃ©rvÃ¡r', 'HU', Decimal('210.00'))
# ('Julie Brandes', 'Å\xa0irvintos', 'LT', Decimal('310.00'))
# ('Boot Terbeck', 'PrzyborÃ³w', 'PL', Decimal('225.00'))
# ('Henryetta Kempster', 'Criuleni', 'MD', Decimal('190.00'))
# ('Mei Scrogges', 'Kolyvanâ€™', 'RU', Decimal('98.00'))
# ('Florinda Cellier', 'Bukowiec', 'PL', Decimal('168.27'))
# ('Gay Skechley', 'Mafang', 'CN', Decimal('124.62'))
# ('Beret Behneke', 'Ginowan', 'JP', Decimal('144.09'))
# ('Adria Koubu', 'Lac du Bonnet', 'CA', Decimal('101.60'))
# ('Karissa Sancraft', 'Pompano Beach', 'US', Decimal('93.13'))
# ('Bentley Gwyneth', 'Zaoshi', 'CN', Decimal('91.84'))
# ('Janeva Buist', 'AlenÃ§on', 'FR', Decimal('133.17'))
# ('Inez Flade', 'Moinhos', 'PT', Decimal('83.99'))
# ('Nicole Linnit', 'Huangzhou', 'CN', Decimal('69.38'))
# ('Michaela Babcock', 'Korsakovo', 'RU', Decimal('119.80'))
# ('Jacquetta Plampin', 'Donggou', 'CN', Decimal('125.00'))
# ('Ynez Hows', 'FlorianÃ³polis', 'BR', Decimal('235.00'))
# ('Elvina McGlynn', 'Miaotang', 'CN', Decimal('75.00'))
# ('Myra Zaczek', 'Vera', 'AR', Decimal('220.00'))
# ('Sabina Corneille', 'Loa Janan', 'ID', Decimal('320.00'))
# ('Leanna Dur', 'Nossa Senhora do Socorro', 'BR', Decimal('210.00'))
# ('Barnabas Casson', 'Litein', 'KE', Decimal('310.00'))
# ('Cornall Pimlock', 'Grzechynia', 'PL', Decimal('225.00'))
# ('Harlie Jindracek', 'Dedza', 'MW', Decimal('190.00'))
# ('Leonora Tullett', 'Homa Bay', 'KE', Decimal('98.00'))
# ('Vale Norwood', 'Atlanta', 'US', Decimal('168.27'))
# ('Kimberli Eisenberg', 'Laramate', 'PE', Decimal('124.62'))
# ('Lisle Scamadin', 'VysokÃ© nad Jizerou', 'CZ', Decimal('144.09'))
# ('Graham Rumford', 'Verkhniy Dashkesan', 'AZ', Decimal('101.60'))
# ('Fredelia Snedden', 'Oenam', 'ID', Decimal('93.13'))
# ('Gawain Willmont', 'Saskylakh', 'RU', Decimal('91.84'))
# ('Brittni Nielson', 'Garagoa', 'CO', Decimal('133.17'))
# ('Monique Fry', 'Nowlamary', 'BD', Decimal('83.99'))
# ('Ogdon Petr', 'Mirabel', 'CA', Decimal('69.38'))
# ('Lance Cheatle', 'Newport Beach', 'US', Decimal('119.80'))
# ('Devonne Yanuk', 'Yangying', 'CN', Decimal('125.00'))
# ('Vaughan Gorch', 'Chiantla', 'GT', Decimal('235.00'))
# ('Terencio Loche', 'Keruguya', 'KE', Decimal('75.00'))
# ('Winnah Laye', 'Cibaregbeg', 'ID', Decimal('220.00'))
# ('Lawrence OCahey', 'Fojo', 'PT', Decimal('320.00'))
# ('Goldie OSherrin', 'BouÃ§as', 'PT', Decimal('210.00'))
# ('Kristoffer Pales', 'Rennes', 'FR', Decimal('310.00'))
# ('Sol Hynam', 'VÃ¤nnÃ¤s', 'SE', Decimal('225.00'))
# ('Kristian Beeken', 'PiÃ±as', 'EC', Decimal('190.00'))
# ('Caterina Rosenzwig', 'Sumberejo', 'ID', Decimal('98.00'))
# ('Carroll Tear', 'Napoli', 'IT', Decimal('168.27'))
# ('Jonell Aiton', 'Karaundi', 'PK', Decimal('124.62'))
# ('Sherye Christmas', 'Buffalo', 'US', Decimal('144.09'))
# ('Natka Featenby', 'Khatanga', 'RU', Decimal('101.60'))
# ('Biddy Spadoni', 'Ebak', 'ID', Decimal('93.13'))
# ('Marcelia Kerswell', 'Condado', 'CU', Decimal('91.84'))
# ('Tove Jaquest', 'Samamiya', 'NG', Decimal('133.17'))
# ('Debbie Noteyoung', 'NahrÄ«n', 'AF', Decimal('83.99'))
# ('Devonne Whal', 'Balboa', 'CO', Decimal('69.38'))
# ('Zena Todari', 'Telgawah', 'ID', Decimal('119.80'))
# ('Kathleen Mac Giolla Pheadair', 'Sucre', 'EC', Decimal('125.00'))
# ('Korney Buffery', 'MethÃ³ni', 'GR', Decimal('235.00'))
# ('Desiri Issac', 'Tinampo', 'PH', Decimal('75.00'))
# ('Serene Steadman', 'Shiquan', 'CN', Decimal('220.00'))
# ('Mano Abrahamson', 'Cercal', 'PT', Decimal('320.00'))
# ('Yardley Eliet', 'Sacramento', 'US', Decimal('210.00'))
# ('Christi Flute', 'Leigu', 'CN', Decimal('310.00'))
# ('Walther Rablin', 'Guangfu', 'CN', Decimal('225.00'))
# ('Sophey Garling', 'Xincheng', 'CN', Decimal('190.00'))
# ('Gavra Breslin', 'Tsotsin-Yurt', 'RU', Decimal('98.00'))
# ('Emmerich Ochterlony', 'Gomel', 'BY', Decimal('168.27'))
# ('Kellina Oates', 'Villa de Soto', 'AR', Decimal('124.62'))
# ('Karee Colchett', 'MontbÃ©liard', 'FR', Decimal('144.09'))
# ('Enrika Marty', 'Rulong', 'CN', Decimal('101.60'))
# ('Cal Rorke', 'Jongorsari', 'ID', Decimal('93.13'))
# ('Barb Murfett', 'Swan Hills', 'CA', Decimal('91.84'))
# ('Jo ONowlan', 'Kafr BaÅ£nÄ\x81', 'SY', Decimal('133.17'))
# ('Egon Lawrance', 'Farinheiras', 'PT', Decimal('83.99'))
# ('Winn Raynes', 'Citangtu Kaler', 'ID', Decimal('69.38'))
# ('Emilie Faircley', 'Ystad', 'SE', Decimal('119.80'))
# ('Antonino McMains', 'Noling', 'PH', Decimal('125.00'))
# ('Megan Beddows', 'Marull', 'AR', Decimal('235.00'))
# ('Haslett Jenkyn', 'Yongning', 'CN', Decimal('75.00'))
# ('Gus Trower', 'Banarankrajan', 'ID', Decimal('220.00'))
# ('Doreen Sothcott', 'Decatur', 'US', Decimal('320.00'))
# ('Allyn Gurnay', 'NghÄ©a HÃ\xa0nh', 'VN', Decimal('210.00'))
# ('Katy Pine', 'Linggou', 'CN', Decimal('310.00'))
# ('Joanie Swindley', 'Zaymishche', 'RU', Decimal('225.00'))
# ('Petronille Scrimgeour', 'San Francisco', 'US', Decimal('190.00'))
# ('Ellis Castanares', 'Jinsha', 'CN', Decimal('98.00'))
# ('Delly Ventum', 'Su-ngai Kolok', 'TH', Decimal('168.27'))
# ('Antonella Ochterlony', 'DobÅ™Ã\xadv', 'CZ', Decimal('124.62'))
# ('Felita Dovey', 'Tianhekou', 'CN', Decimal('144.09'))
# ('Hall Everil', 'Richky', 'UA', Decimal('101.60'))
# ('Dodi Basindale', 'Niquero', 'CU', Decimal('93.13'))
# ('Gabrielle Coxall', 'Junxi', 'CN', Decimal('91.84'))
# ('Jobie Coaten', 'San Pedro de Atacama', 'CL', Decimal('133.17'))
# ('Dell Hellsdon', 'Å\xa0avnik', 'ME', Decimal('83.99'))
# ('Dorie Cammell', 'Zamoskvorechâ€™ye', 'RU', Decimal('69.38'))
# ('Rayna Strathearn', 'Guanchao', 'CN', Decimal('119.80'))
# ('Brendin Meedendorpe', 'Kudahuvadhoo', 'MV', Decimal('125.00'))
# ('Raquel Borham', 'Toledo', 'ES', Decimal('235.00'))
# ('Tildy Shanks', 'Cabog', 'PH', Decimal('75.00'))
# ('Alisander Shoebottom', 'Kajatian', 'PH', Decimal('220.00'))
# ('Brandon Cocklie', 'Gustavia', 'BL', Decimal('320.00'))
# ('Hebert Aubin', 'Barrancas', 'CO', Decimal('210.00'))
# ('Aldin Purrier', 'Hamburg Bramfeld', 'DE', Decimal('310.00'))
# ('Willi Voce', 'Huangjin', 'CN', Decimal('225.00'))
# ('Roxine Humphries', 'Cruces', 'CU', Decimal('190.00'))
# ('Guthrey Juara', 'Sam Roi Yot', 'TH', Decimal('98.00'))
# ('Mariel Bourdel', 'Rainis', 'ID', Decimal('168.27'))
# ('Cissiee Gobeau', 'Chust Shahri', 'UZ', Decimal('124.62'))
# ('Bonnee Keller', 'Shentang', 'CN', Decimal('144.09'))
# ('Nelie Cleare', 'Dadian', 'CN', Decimal('101.60'))
# ('Hurlee Dhennin', 'Zhiqu', 'CN', Decimal('93.13'))
# ('Far Emmanuele', 'SkÃ¶vde', 'SE', Decimal('91.84'))
# ('Jilly Bursnoll', 'Jiangya', 'CN', Decimal('133.17'))
# ('Skippy McIlwain', 'TÃ¢y Há»“', 'VN', Decimal('83.99'))
# ('Ara McWard', 'ÐœÐ°Ñ‚ÐµÑ˜Ñ‡Ðµ', 'MK', Decimal('69.38'))
# ('Elvira Beverstock', 'Tojeira', 'PT', Decimal('119.80'))
# ('Westbrooke Blindt', 'Qiryat Yam', 'IL', Decimal('125.00'))
# ('Maribelle Allcroft', 'Motupe', 'PE', Decimal('235.00'))
# ('Roosevelt Grigg', 'Jielin', 'CN', Decimal('75.00'))
# ('Jard Adderson', 'Shangwuzhuang', 'CN', Decimal('220.00'))
# ('Steward Pettinger', 'Nangalimang', 'ID', Decimal('320.00'))
# ('Barby Noell', 'Perrelos', 'PH', Decimal('210.00'))
# ('Bertrand Bilton', 'JesÃºs MarÃ\xada', 'AR', Decimal('310.00'))
# ('Emilee Riddeough', 'Oral', 'KZ', Decimal('225.00'))
# ('Agretha Dutteridge', 'Otjiwarongo', 'NA', Decimal('190.00'))
# ('Ferrel Jeratt', 'Jindou', 'CN', Decimal('98.00'))
# ('Selia Grigoroni', 'Bun Barat', 'ID', Decimal('168.27'))
# ('Celine Coopland', 'Pajaten', 'ID', Decimal('124.62'))
# ('Danna ONion', 'MorfovoÃºni', 'GR', Decimal('144.09'))
# ('Cornelia Rowth', 'Enzan', 'JP', Decimal('101.60'))
# ('Horatio Codi', 'Hatsâ€™avan', 'AM', Decimal('93.13'))
# ('Bibbie Bover', 'Bazar-Korgon', 'KG', Decimal('91.84'))
# ('Lise Fegan', 'DÅ« LaÄ«nah', 'AF', Decimal('133.17'))
# ('Berte Cornall', 'DÄ\x81rchulÄ\x81', 'NP', Decimal('83.99'))
# ('King Hillin', 'Wang Nam Khiao', 'TH', Decimal('69.38'))
# ('Selena Relton', 'Singojuruh', 'ID', Decimal('119.80'))
# ('Virgie Belhomme', 'Kasese', 'UG', Decimal('125.00'))
# ('Brunhilda Beeze', 'Ribas do Rio Pardo', 'BR', Decimal('235.00'))
# ('Colver McChesney', 'Parengan', 'ID', Decimal('75.00'))
# ('Dominick Crafts', 'Pul-e SangÄ«', 'AF', Decimal('220.00'))
# ('Tiertza Barford', 'Volokolamsk', 'RU', Decimal('320.00'))
# ('Hastie Charopen', 'Tuburan', 'PH', Decimal('210.00'))
# ('Doug Logg', 'Mozhaysk', 'RU', Decimal('310.00'))
# ('Clive Crammy', 'Shiban', 'CN', Decimal('225.00'))
# ('Ximenes Carnachen', 'Kostanay', 'KZ', Decimal('190.00'))
# ('Jere Whitebrook', 'Kotaagung', 'ID', Decimal('98.00'))
# ('Gabe Boyan', 'Novi Slankamen', 'RS', Decimal('168.27'))
# ('Gennifer Koenen', 'Cayambe', 'EC', Decimal('124.62'))
# ('Tedda Plumridge', 'Bapska', 'HR', Decimal('144.09'))
# ('Lexie Spinetti', 'Shijia', 'CN', Decimal('101.60'))
# ('Anastasia Baudy', 'Jangdam', 'CN', Decimal('93.13'))
# ('Melisandra Mungham', 'Xinhua', 'CN', Decimal('91.84'))
# ('Dian Collough', 'Mayong', 'CN', Decimal('133.17'))
# ('Pail Duignan', 'TanÅ«mah', 'SA', Decimal('83.99'))
# ('Rivi Bowart', 'Kushtia', 'BD', Decimal('69.38'))
# ('Carlye Chiswell', 'TraganÃ³n', 'GR', Decimal('119.80'))
# ('Braden Bartolacci', 'Royan', 'FR', Decimal('125.00'))
# ('Hedi Chadwin', 'Huaishu', 'CN', Decimal('235.00'))
# ('Annamarie Taylot', 'Helsingborg', 'SE', Decimal('75.00'))
# ('Rhetta Nevill', 'Lupao', 'PH', Decimal('220.00'))
# ('Raye Fyldes', 'MompÃ³s', 'CO', Decimal('320.00'))
# ('Kellby Quarterman', 'Hanggan', 'PH', Decimal('210.00'))
# ('Raye Rossant', 'Orikum', 'AL', Decimal('310.00'))
# ('Aaron Cromley', 'Cruz', 'PT', Decimal('225.00'))
# ('Morganne Brecknell', 'Naryn', 'KG', Decimal('190.00'))
# ('Dieter Crannis', 'ViÃ±ales', 'CU', Decimal('98.00'))
# ('Kerri Barnes', 'Posse', 'BR', Decimal('168.27'))
# ('Adaline Reichartz', 'Jetaral', 'CN', Decimal('124.62'))
# ('Ally McBrearty', 'Mundolsheim', 'FR', Decimal('144.09'))
# ('Theda Jagoe', 'MutÄ\x81 KhÄ\x81n', 'AF', Decimal('101.60'))
# ('Jethro Fenwick', 'Villa del Rosario', 'CO', Decimal('93.13'))
# ('Ezri Gouck', 'InÄ\x8dukalns', 'LV', Decimal('91.84'))
# ('Charisse Risso', 'KavallÃ¡ri', 'GR', Decimal('133.17'))
# ('Florella McMullen', 'Yongâ€™an', 'CN', Decimal('83.99'))
# ('Raven Cawkwell', 'Lembursawah', 'ID', Decimal('69.38'))
# ('Mable Browncey', 'Paninggaran', 'ID', Decimal('119.80'))
# ('Essie Hagland', 'Spas-Zaulok', 'RU', Decimal('125.00'))
# ('Valida Greenhill', 'New Pandanon', 'PH', Decimal('235.00'))
# ('Malinde Firbanks', 'Pilang', 'ID', Decimal('75.00'))
# ('Persis Chipchase', 'Suwaru', 'ID', Decimal('220.00'))
# ('Demetris McGibbon', 'Napoli', 'IT', Decimal('320.00'))
# ('Natala Stobbe', 'LidingÃ¶', 'SE', Decimal('210.00'))
# ('Shandy Sefton', 'Rakhmanovo', 'RU', Decimal('310.00'))
# ('Sander Maloney', 'Hallsberg', 'SE', Decimal('225.00'))
# ('Ellis Kops', 'Rouen', 'FR', Decimal('190.00'))
# ('Yankee Penright', 'Kuznechikha', 'RU', Decimal('98.00'))
# ('Wandie Yeeles', 'PÃ\xadritu', 'VE', Decimal('168.27'))
# ('Tanner Garner', 'Lazaro Cardenas', 'MX', Decimal('124.62'))
# ('Maryjo Strangwood', 'Kortowo', 'PL', Decimal('144.09'))
# ('Dorise Reames', 'VargÃ¶n', 'SE', Decimal('101.60'))
# ('Sly Fullwood', 'Urcos', 'PE', Decimal('93.13'))
# ('Korney OCarney', 'North Bay', 'CA', Decimal('91.84'))
# ('Rorie Colicot', 'Pantian', 'CN', Decimal('133.17'))
# ('Carol-jean Sodory', 'Hongwei', 'CN', Decimal('83.99'))
# ('Ludwig Fuxman', 'Iranduba', 'BR', Decimal('69.38'))
# ('Gloriane Allsepp', 'Tabatinga', 'BR', Decimal('119.80'))
# ('Christoper Myrkus', 'Ziketan', 'CN', Decimal('125.00'))
# ('Steward Doyland', 'Masipi West', 'PH', Decimal('235.00'))
# ('Jenilee Ricardou', 'Uyutne', 'UA', Decimal('75.00'))
# ('Riccardo Jahner', 'Taksimo', 'RU', Decimal('220.00'))
# ('Leonard Fuxman', 'La Clotilde', 'AR', Decimal('320.00'))
# ('Ali Einchcombe', 'Hushi', 'CN', Decimal('210.00'))
# ('Cynthea OHickee', 'Aulnay-sous-Bois', 'FR', Decimal('310.00'))
# ('Renata Vlach', 'Babice', 'PL', Decimal('225.00'))
# ('Manuel Gloyens', 'Xiadu', 'CN', Decimal('190.00'))
# ('Jerrome Drohan', 'Sukadana', 'ID', Decimal('98.00'))
# ('Karoly Ivie', 'Thatta', 'PK', Decimal('168.27'))
# ('Jory Glave', 'Salogon', 'PH', Decimal('124.62'))
# ('Charin Pinckard', 'Qinling Jieban', 'CN', Decimal('144.09'))
# ('Malina Pengelly', 'Rawawilis', 'ID', Decimal('101.60'))
# ('Marillin Dennehy', 'Foundiougne', 'SN', Decimal('93.13'))
# ('Noel Ladley', 'Yachimata', 'JP', Decimal('91.84'))
# ('Gail Grigaut', 'Pasar', 'ID', Decimal('133.17'))
# ('Quinn Stamps', 'Kota Kinabalu', 'MY', Decimal('83.99'))
# ('Odilia Bockett', 'Nuits-Saint-Georges', 'FR', Decimal('69.38'))
# ('Mikael OKeevan', 'Cruz Alta', 'BR', Decimal('119.80'))
# ('Egbert Mollnar', 'Pavlysh', 'UA', Decimal('125.00'))
# ('Howie Flamank', 'Santa Maria', 'BR', Decimal('235.00'))
# ('Judy Swainson', 'Zdenci', 'HR', Decimal('75.00'))
# ('Dulcie Lax', 'VelkÃ© Pavlovice', 'CZ', Decimal('220.00'))
# ('Nelli Myrie', 'Å\x81Ä™knica', 'PL', Decimal('320.00'))
# ('Althea Jaggli', 'Lazaro Cardenas', 'MX', Decimal('210.00'))
# ('Row Colchett', 'Marang', 'ID', Decimal('310.00'))
# ('Adlai Arnull', 'Qalâ€˜at BÄ«shah', 'SA', Decimal('225.00'))
# ('Paloma Spellar', 'Florencia', 'CO', Decimal('190.00'))
# ('Hyacintha Hanne', 'Phoenix', 'US', Decimal('98.00'))
# ('Mattie Brenston', 'Daba', 'CN', Decimal('168.27'))
# ('Quintus Parcells', 'Oslo', 'NO', Decimal('124.62'))
# ('Sue Fargie', 'TeresÃ³polis', 'BR', Decimal('144.09'))
# ('Amaleta Brattan', 'Caringin Lor', 'ID', Decimal('101.60'))
# ('Willow Burmingham', 'Kanbe', 'MM', Decimal('93.13'))
# ('Donni Tatem', 'Fairbanks', 'US', Decimal('91.84'))
# ('Mary Jellett', 'Pasadena', 'US', Decimal('133.17'))
# ('Aube Francescuzzi', 'PÃ©rigny', 'FR', Decimal('83.99'))
# ('Fanni Caccavella', 'Panacan', 'PH', Decimal('69.38'))
# ('Allie Turbard', 'Dalam', 'ID', Decimal('119.80'))
# ('Nadine Cudbird', 'Kuandian', 'CN', Decimal('125.00'))
# ('Ginelle Finnimore', 'Ujar', 'AZ', Decimal('235.00'))
# ('Rici Bollin', 'Maszkienice', 'PL', Decimal('75.00'))
# ('Yvon Chasmor', 'Corralito', 'AR', Decimal('220.00'))
# ('Sindee Drynan', 'Malie', 'WS', Decimal('320.00'))
# ('Kim McCloughlin', 'Vom', 'NG', Decimal('210.00'))
# ('Jarib Cranke', 'ShÄ«eli', 'KZ', Decimal('310.00'))
# ('Cordelia Whicher', 'Ã‰pinal', 'FR', Decimal('225.00'))
# ('Adria Heller', 'Sungi Liput', 'ID', Decimal('190.00'))
# ('Ash Boise', 'Shouxihu', 'CN', Decimal('98.00'))
# ('Ravid Josephsen', 'Vimmerby', 'SE', Decimal('168.27'))
# ('Belle Priver', 'Chuchkovo', 'RU', Decimal('124.62'))
# ('Wanda Ramas', 'Ipojuca', 'BR', Decimal('144.09'))
# ...
# ('Lisle Scamadin', 'VysokÃ© nad Jizerou', 'CZ', Decimal('93.13'))
# ('Fredelia Snedden', 'Oenam', 'ID', Decimal('91.84'))
# ('Anatole Desforges', 'Wassa-Akropong', 'GH', Decimal('133.17'))
# ('Brittni Nielson', 'Garagoa', 'CO', Decimal('83.99'))
# ('Paddie Tellenbrok', 'Novozybkov', 'RU', Decimal('69.38'))
# ('Monique Fry', 'Nowlamary', 'BD', Decimal('119.80'))
# ('Ogdon Petr', 'Mirabel', 'CA', Decimal('125.00'))
# ('Lance Cheatle', 'Newport Beach', 'US', Decimal('235.00'))
# ('Devonne Yanuk', 'Yangying', 'CN', Decimal('75.00'))
# ('Vaughan Gorch', 'Chiantla', 'GT', Decimal('220.00'))
# ('Terencio Loche', 'Keruguya', 'KE', Decimal('320.00'))
# ('Winnah Laye', 'Cibaregbeg', 'ID', Decimal('210.00'))
# ('Lawrence OCahey', 'Fojo', 'PT', Decimal('310.00'))
# ('Goldie OSherrin', 'BouÃ§as', 'PT', Decimal('225.00'))
# ('Kristoffer Pales', 'Rennes', 'FR', Decimal('190.00'))
# ('Sol Hynam', 'VÃ¤nnÃ¤s', 'SE', Decimal('98.00'))
# ('Kristian Beeken', 'PiÃ±as', 'EC', Decimal('168.27'))
# ('Caterina Rosenzwig', 'Sumberejo', 'ID', Decimal('124.62'))
# ('Carroll Tear', 'Napoli', 'IT', Decimal('144.09'))
# ('Jonell Aiton', 'Karaundi', 'PK', Decimal('101.60'))
# ('Sherye Christmas', 'Buffalo', 'US', Decimal('93.13'))
# ('Biddy Spadoni', 'Ebak', 'ID', Decimal('91.84'))
# ('Brynn Roset', 'Trujillo', 'HN', Decimal('133.17'))
# ('Tove Jaquest', 'Samamiya', 'NG', Decimal('83.99'))
# ('Lorne Boldry', 'Decatur', 'US', Decimal('69.38'))
# ('Debbie Noteyoung', 'NahrÄ«n', 'AF', Decimal('119.80'))
# ('Devonne Whal', 'Balboa', 'CO', Decimal('125.00'))
# ('Zena Todari', 'Telgawah', 'ID', Decimal('235.00'))
# ('Kathleen Mac Giolla Pheadair', 'Sucre', 'EC', Decimal('75.00'))
# ('Korney Buffery', 'MethÃ³ni', 'GR', Decimal('220.00'))
# ('Desiri Issac', 'Tinampo', 'PH', Decimal('320.00'))
# ('Serene Steadman', 'Shiquan', 'CN', Decimal('210.00'))
# ('Mano Abrahamson', 'Cercal', 'PT', Decimal('310.00'))
# ('Yardley Eliet', 'Sacramento', 'US', Decimal('225.00'))
# ('Christi Flute', 'Leigu', 'CN', Decimal('190.00'))
# ('Walther Rablin', 'Guangfu', 'CN', Decimal('98.00'))
# ('Sophey Garling', 'Xincheng', 'CN', Decimal('168.27'))
# ('Gavra Breslin', 'Tsotsin-Yurt', 'RU', Decimal('124.62'))
# ('Emmerich Ochterlony', 'Gomel', 'BY', Decimal('144.09'))
# ('Kellina Oates', 'Villa de Soto', 'AR', Decimal('101.60'))
# ('Karee Colchett', 'MontbÃ©liard', 'FR', Decimal('93.13'))
# ('Cal Rorke', 'Jongorsari', 'ID', Decimal('91.84'))
# ('Jehu Dauney', 'Tugu', 'ID', Decimal('133.17'))
# ('Jo ONowlan', 'Kafr BaÅ£nÄ\x81', 'SY', Decimal('83.99'))
# ('Hermine Dorton', 'Olszyna', 'PL', Decimal('69.38'))
# ('Egon Lawrance', 'Farinheiras', 'PT', Decimal('119.80'))
# ('Winn Raynes', 'Citangtu Kaler', 'ID', Decimal('125.00'))
# ('Emilie Faircley', 'Ystad', 'SE', Decimal('235.00'))
# ('Antonino McMains', 'Noling', 'PH', Decimal('75.00'))
# ('Megan Beddows', 'Marull', 'AR', Decimal('220.00'))
# ('Haslett Jenkyn', 'Yongning', 'CN', Decimal('320.00'))
# ('Gus Trower', 'Banarankrajan', 'ID', Decimal('210.00'))
# ('Doreen Sothcott', 'Decatur', 'US', Decimal('310.00'))
# ('Allyn Gurnay', 'NghÄ©a HÃ\xa0nh', 'VN', Decimal('225.00'))
# ('Katy Pine', 'Linggou', 'CN', Decimal('190.00'))
# ('Joanie Swindley', 'Zaymishche', 'RU', Decimal('98.00'))
# ('Petronille Scrimgeour', 'San Francisco', 'US', Decimal('168.27'))
# ('Ellis Castanares', 'Jinsha', 'CN', Decimal('124.62'))
# ('Delly Ventum', 'Su-ngai Kolok', 'TH', Decimal('144.09'))
# ('Antonella Ochterlony', 'DobÅ™Ã\xadv', 'CZ', Decimal('101.60'))
# ('Felita Dovey', 'Tianhekou', 'CN', Decimal('93.13'))
# ('Dodi Basindale', 'Niquero', 'CU', Decimal('91.84'))
# ('Krishnah Pearch', 'LenÃ§Ã³is Paulista', 'BR', Decimal('133.17'))
# ('Jobie Coaten', 'San Pedro de Atacama', 'CL', Decimal('83.99'))
# ('Borden Hacking', 'Made', 'ID', Decimal('69.38'))
# ('Dell Hellsdon', 'Å\xa0avnik', 'ME', Decimal('119.80'))
# ('Dorie Cammell', 'Zamoskvorechâ€™ye', 'RU', Decimal('125.00'))
# ('Rayna Strathearn', 'Guanchao', 'CN', Decimal('235.00'))
# ('Brendin Meedendorpe', 'Kudahuvadhoo', 'MV', Decimal('75.00'))
# ('Raquel Borham', 'Toledo', 'ES', Decimal('220.00'))
# ('Tildy Shanks', 'Cabog', 'PH', Decimal('320.00'))
# ('Alisander Shoebottom', 'Kajatian', 'PH', Decimal('210.00'))
# ('Brandon Cocklie', 'Gustavia', 'BL', Decimal('310.00'))
# ('Hebert Aubin', 'Barrancas', 'CO', Decimal('225.00'))
# ('Aldin Purrier', 'Hamburg Bramfeld', 'DE', Decimal('190.00'))
# ('Willi Voce', 'Huangjin', 'CN', Decimal('98.00'))
# ('Roxine Humphries', 'Cruces', 'CU', Decimal('168.27'))
# ('Guthrey Juara', 'Sam Roi Yot', 'TH', Decimal('124.62'))
# ('Mariel Bourdel', 'Rainis', 'ID', Decimal('144.09'))
# ('Cissiee Gobeau', 'Chust Shahri', 'UZ', Decimal('101.60'))
# ('Bonnee Keller', 'Shentang', 'CN', Decimal('93.13'))
# ('Hurlee Dhennin', 'Zhiqu', 'CN', Decimal('91.84'))
# ('Charil Fanton', 'Clifden', 'IE', Decimal('133.17'))
# ('Jilly Bursnoll', 'Jiangya', 'CN', Decimal('83.99'))
# ('Wakefield Strotton', 'Presa', 'PT', Decimal('69.38'))
# ('Skippy McIlwain', 'TÃ¢y Há»“', 'VN', Decimal('119.80'))
# ('Ara McWard', 'ÐœÐ°Ñ‚ÐµÑ˜Ñ‡Ðµ', 'MK', Decimal('125.00'))
# ('Elvira Beverstock', 'Tojeira', 'PT', Decimal('235.00'))
# ('Westbrooke Blindt', 'Qiryat Yam', 'IL', Decimal('75.00'))
# ('Maribelle Allcroft', 'Motupe', 'PE', Decimal('220.00'))
# ('Roosevelt Grigg', 'Jielin', 'CN', Decimal('320.00'))
# ('Jard Adderson', 'Shangwuzhuang', 'CN', Decimal('210.00'))
# ('Steward Pettinger', 'Nangalimang', 'ID', Decimal('310.00'))
# ('Barby Noell', 'Perrelos', 'PH', Decimal('225.00'))
# ('Bertrand Bilton', 'JesÃºs MarÃ\xada', 'AR', Decimal('190.00'))
# ('Emilee Riddeough', 'Oral', 'KZ', Decimal('98.00'))
# ('Agretha Dutteridge', 'Otjiwarongo', 'NA', Decimal('168.27'))
# ('Ferrel Jeratt', 'Jindou', 'CN', Decimal('124.62'))
# ('Selia Grigoroni', 'Bun Barat', 'ID', Decimal('144.09'))
# ('Celine Coopland', 'Pajaten', 'ID', Decimal('101.60'))
# ('Danna ONion', 'MorfovoÃºni', 'GR', Decimal('93.13'))
# ('Horatio Codi', 'Hatsâ€™avan', 'AM', Decimal('91.84'))
# ('Dru Priscott', 'DolnÃ\xad DvoÅ™iÅ¡tÄ›', 'CZ', Decimal('133.17'))
# ('Lise Fegan', 'DÅ« LaÄ«nah', 'AF', Decimal('83.99'))
# ('Faith Grushin', 'Washington', 'US', Decimal('69.38'))
# ('Berte Cornall', 'DÄ\x81rchulÄ\x81', 'NP', Decimal('119.80'))
# ('King Hillin', 'Wang Nam Khiao', 'TH', Decimal('125.00'))
# ('Selena Relton', 'Singojuruh', 'ID', Decimal('235.00'))
# ('Virgie Belhomme', 'Kasese', 'UG', Decimal('75.00'))
# ('Brunhilda Beeze', 'Ribas do Rio Pardo', 'BR', Decimal('220.00'))
# ('Colver McChesney', 'Parengan', 'ID', Decimal('320.00'))
# ('Dominick Crafts', 'Pul-e SangÄ«', 'AF', Decimal('210.00'))
# ('Tiertza Barford', 'Volokolamsk', 'RU', Decimal('310.00'))
# ('Hastie Charopen', 'Tuburan', 'PH', Decimal('225.00'))
# ('Doug Logg', 'Mozhaysk', 'RU', Decimal('190.00'))
# ('Clive Crammy', 'Shiban', 'CN', Decimal('98.00'))
# ('Ximenes Carnachen', 'Kostanay', 'KZ', Decimal('168.27'))
# ('Jere Whitebrook', 'Kotaagung', 'ID', Decimal('124.62'))
# ('Gabe Boyan', 'Novi Slankamen', 'RS', Decimal('144.09'))
# ('Gennifer Koenen', 'Cayambe', 'EC', Decimal('101.60'))
# ('Tedda Plumridge', 'Bapska', 'HR', Decimal('93.13'))
# ('Anastasia Baudy', 'Jangdam', 'CN', Decimal('91.84'))
# ('Anna-maria Neilan', 'Nong Saeng', 'TH', Decimal('133.17'))
# ('Dian Collough', 'Mayong', 'CN', Decimal('83.99'))
# ('Elayne Karet', 'Xiaosong', 'CN', Decimal('69.38'))
# ('Pail Duignan', 'TanÅ«mah', 'SA', Decimal('119.80'))
# ('Rivi Bowart', 'Kushtia', 'BD', Decimal('125.00'))
# ('Carlye Chiswell', 'TraganÃ³n', 'GR', Decimal('235.00'))
# ('Braden Bartolacci', 'Royan', 'FR', Decimal('75.00'))
# ('Hedi Chadwin', 'Huaishu', 'CN', Decimal('220.00'))
# ('Annamarie Taylot', 'Helsingborg', 'SE', Decimal('320.00'))
# ('Rhetta Nevill', 'Lupao', 'PH', Decimal('210.00'))
# ('Raye Fyldes', 'MompÃ³s', 'CO', Decimal('310.00'))
# ('Kellby Quarterman', 'Hanggan', 'PH', Decimal('225.00'))
# ('Raye Rossant', 'Orikum', 'AL', Decimal('190.00'))
# ('Aaron Cromley', 'Cruz', 'PT', Decimal('98.00'))
# ('Morganne Brecknell', 'Naryn', 'KG', Decimal('168.27'))
# ('Dieter Crannis', 'ViÃ±ales', 'CU', Decimal('124.62'))
# ('Kerri Barnes', 'Posse', 'BR', Decimal('144.09'))
# ('Adaline Reichartz', 'Jetaral', 'CN', Decimal('101.60'))
# ('Ally McBrearty', 'Mundolsheim', 'FR', Decimal('93.13'))
# ('Jethro Fenwick', 'Villa del Rosario', 'CO', Decimal('91.84'))
# ('Bambie Frears', 'Zhanjiang', 'CN', Decimal('133.17'))
# ('Charisse Risso', 'KavallÃ¡ri', 'GR', Decimal('83.99'))
# ('Leanna Chapelhow', 'Aix-en-Provence', 'FR', Decimal('69.38'))
# ('Florella McMullen', 'Yongâ€™an', 'CN', Decimal('119.80'))
# ('Raven Cawkwell', 'Lembursawah', 'ID', Decimal('125.00'))
# ('Mable Browncey', 'Paninggaran', 'ID', Decimal('235.00'))
# ('Essie Hagland', 'Spas-Zaulok', 'RU', Decimal('75.00'))
# ('Valida Greenhill', 'New Pandanon', 'PH', Decimal('220.00'))
# ('Malinde Firbanks', 'Pilang', 'ID', Decimal('320.00'))
# ('Persis Chipchase', 'Suwaru', 'ID', Decimal('210.00'))
# ('Demetris McGibbon', 'Napoli', 'IT', Decimal('310.00'))
# ('Natala Stobbe', 'LidingÃ¶', 'SE', Decimal('225.00'))
# ('Shandy Sefton', 'Rakhmanovo', 'RU', Decimal('190.00'))
# ('Sander Maloney', 'Hallsberg', 'SE', Decimal('98.00'))
# ('Ellis Kops', 'Rouen', 'FR', Decimal('168.27'))
# ('Yankee Penright', 'Kuznechikha', 'RU', Decimal('124.62'))
# ('Wandie Yeeles', 'PÃ\xadritu', 'VE', Decimal('144.09'))
# ('Tanner Garner', 'Lazaro Cardenas', 'MX', Decimal('101.60'))
# ('Maryjo Strangwood', 'Kortowo', 'PL', Decimal('93.13'))
# ('Sly Fullwood', 'Urcos', 'PE', Decimal('91.84'))
# ('Florella Reape', 'LÃ©rida', 'CO', Decimal('133.17'))
# ('Rorie Colicot', 'Pantian', 'CN', Decimal('83.99'))
# ('Nathanil Eykel', 'ÅŒdachÅ\x8d-Å\x8dda', 'JP', Decimal('69.38'))
# ('Carol-jean Sodory', 'Hongwei', 'CN', Decimal('119.80'))
# ('Ludwig Fuxman', 'Iranduba', 'BR', Decimal('125.00'))
# ('Gloriane Allsepp', 'Tabatinga', 'BR', Decimal('235.00'))
# ('Christoper Myrkus', 'Ziketan', 'CN', Decimal('75.00'))
# ('Steward Doyland', 'Masipi West', 'PH', Decimal('220.00'))
# ('Jenilee Ricardou', 'Uyutne', 'UA', Decimal('320.00'))
# ('Riccardo Jahner', 'Taksimo', 'RU', Decimal('210.00'))
# ('Leonard Fuxman', 'La Clotilde', 'AR', Decimal('310.00'))
# ('Ali Einchcombe', 'Hushi', 'CN', Decimal('225.00'))
# ('Cynthea OHickee', 'Aulnay-sous-Bois', 'FR', Decimal('190.00'))
# ('Renata Vlach', 'Babice', 'PL', Decimal('98.00'))
# ('Manuel Gloyens', 'Xiadu', 'CN', Decimal('168.27'))
# ('Jerrome Drohan', 'Sukadana', 'ID', Decimal('124.62'))
# ('Karoly Ivie', 'Thatta', 'PK', Decimal('144.09'))
# ('Jory Glave', 'Salogon', 'PH', Decimal('101.60'))
# ('Charin Pinckard', 'Qinling Jieban', 'CN', Decimal('93.13'))
# ('Marillin Dennehy', 'Foundiougne', 'SN', Decimal('91.84'))
# ('Laina Thurborn', 'DzÃ¼Ã¼nkharaa', 'MN', Decimal('133.17'))
# ('Gail Grigaut', 'Pasar', 'ID', Decimal('83.99'))
# ('Gordan Kneeshaw', 'Terek', 'RU', Decimal('69.38'))
# ('Quinn Stamps', 'Kota Kinabalu', 'MY', Decimal('119.80'))
# ('Odilia Bockett', 'Nuits-Saint-Georges', 'FR', Decimal('125.00'))
# ('Mikael OKeevan', 'Cruz Alta', 'BR', Decimal('235.00'))
# ('Egbert Mollnar', 'Pavlysh', 'UA', Decimal('75.00'))
# ('Howie Flamank', 'Santa Maria', 'BR', Decimal('220.00'))
# ('Judy Swainson', 'Zdenci', 'HR', Decimal('320.00'))
# ('Dulcie Lax', 'VelkÃ© Pavlovice', 'CZ', Decimal('210.00'))
# ('Nelli Myrie', 'Å\x81Ä™knica', 'PL', Decimal('310.00'))
# ('Althea Jaggli', 'Lazaro Cardenas', 'MX', Decimal('225.00'))
# ('Row Colchett', 'Marang', 'ID', Decimal('190.00'))
# ('Adlai Arnull', 'Qalâ€˜at BÄ«shah', 'SA', Decimal('98.00'))
# ('Paloma Spellar', 'Florencia', 'CO', Decimal('168.27'))
# ('Hyacintha Hanne', 'Phoenix', 'US', Decimal('124.62'))
# ('Mattie Brenston', 'Daba', 'CN', Decimal('144.09'))
# ('Quintus Parcells', 'Oslo', 'NO', Decimal('101.60'))
# ('Sue Fargie', 'TeresÃ³polis', 'BR', Decimal('93.13'))
# ('Willow Burmingham', 'Kanbe', 'MM', Decimal('91.84'))
# ('Fawnia Bartosch', 'KhÄ\x81ndbÄ\x81ri', 'NP', Decimal('133.17'))
# ('Mary Jellett', 'Pasadena', 'US', Decimal('83.99'))
# ('Todd Riglesford', 'Barra', 'PH', Decimal('69.38'))
# ('Aube Francescuzzi', 'PÃ©rigny', 'FR', Decimal('119.80'))
# ('Fanni Caccavella', 'Panacan', 'PH', Decimal('125.00'))
# ('Allie Turbard', 'Dalam', 'ID', Decimal('235.00'))
# ('Nadine Cudbird', 'Kuandian', 'CN', Decimal('75.00'))
# ('Ginelle Finnimore', 'Ujar', 'AZ', Decimal('220.00'))
# ('Rici Bollin', 'Maszkienice', 'PL', Decimal('320.00'))
# ('Yvon Chasmor', 'Corralito', 'AR', Decimal('210.00'))
# ('Sindee Drynan', 'Malie', 'WS', Decimal('310.00'))
# ('Kim McCloughlin', 'Vom', 'NG', Decimal('225.00'))
# ('Jarib Cranke', 'ShÄ«eli', 'KZ', Decimal('190.00'))
# ('Cordelia Whicher', 'Ã‰pinal', 'FR', Decimal('98.00'))
# ('Adria Heller', 'Sungi Liput', 'ID', Decimal('168.27'))
# ('Ash Boise', 'Shouxihu', 'CN', Decimal('124.62'))
# ('Ravid Josephsen', 'Vimmerby', 'SE', Decimal('144.09'))
# ('Belle Priver', 'Chuchkovo', 'RU', Decimal('101.60'))
# ('Wanda Ramas', 'Ipojuca', 'BR', Decimal('93.13'))
# ('Mellicent Philliphs', 'MaracanaÃº', 'BR', Decimal('91.84'))
# ('Reggie Hallaways', 'Zhongluotan', 'CN', Decimal('133.17'))
# ('Melodee Gartshore', 'Santa Cruz', 'US', Decimal('83.99'))
# ('Giffy Wreath', 'Correia Pinto', 'BR', Decimal('69.38'))
# ('Heida Bohden', 'Slavgorod', 'RU', Decimal('119.80'))
# ('Saw Aspenlon', 'Almafuerte', 'AR', Decimal('125.00'))
# ('Jenda Castellino', 'Delong', 'CN', Decimal('235.00'))
# ('Bobby Blazewski', 'Xinglongchang', 'CN', Decimal('75.00'))
# ('Boniface Giovannilli', 'SzydÅ‚owo', 'PL', Decimal('220.00'))
# ('Halette OHanley', 'Hedong', 'CN', Decimal('320.00'))
# ('Herculie Eastment', 'Bulu', 'ID', Decimal('210.00'))
# ('Virginie Lammas', 'Syanno', 'BY', Decimal('310.00'))
# ('Zorine Delacourt', 'Mesopotam', 'AL', Decimal('225.00'))
# ('Isidro Chelam', 'Vladikavkaz', 'RU', Decimal('190.00'))
# ('Annmarie Bountiff', 'Rislane', 'MA', Decimal('98.00'))
# ('Sid Oultram', 'Tiblawan', 'PH', Decimal('168.27'))
# ('Patrizia Kunrad', 'Chengnan', 'CN', Decimal('124.62'))
# ('Marillin Tieman', 'Takayama', 'JP', Decimal('144.09'))
# ('Rodrigo DAlessio', 'Siparia', 'TT', Decimal('101.60'))
# ('Gigi Trunchion', 'Khanino', 'RU', Decimal('93.13'))
# ('Dannye Passmore', 'BÄ›lÃ¡ pod BezdÄ›zem', 'CZ', Decimal('91.84'))
# ('Carree Jeffree', 'Tetaf', 'ID', Decimal('133.17'))
# ('Ardene Davydenko', 'Abuko', 'GM', Decimal('83.99'))
# ('Lethia Bodechon', 'VÃ¤nersborg', 'SE', Decimal('69.38'))
# ('Harriott Manby', 'Limbe', 'CM', Decimal('119.80'))
# ('Kissie Gosford', 'Dusun Desa Bunter', 'ID', Decimal('125.00'))
# ('Isador Saffen', 'Narathiwat', 'TH', Decimal('235.00'))
# ('Sheela Stein', 'Salt Lake City', 'US', Decimal('75.00'))
# ('Dal Raper', 'Yanxi', 'CN', Decimal('220.00'))
# ('Gauthier Sapshed', 'Ahmadpur SiÄ\x81l', 'PK', Decimal('320.00'))
# ('Gizela Northover', 'Xin Bulag', 'CN', Decimal('210.00'))
# ('Taffy Shipcott', 'Pateh Sam', 'GM', Decimal('310.00'))
# ('Forster Pervew', 'Kerikeri', 'NZ', Decimal('225.00'))
# ('Arlette Magauran', 'Vanadzor', 'AM', Decimal('190.00'))
# ('Jameson Yaknov', 'Mulyoagung', 'ID', Decimal('98.00'))
# ('Esdras Scoffins', 'Sumberbening', 'ID', Decimal('168.27'))
# ('Gradey OGready', 'Hetian', 'CN', Decimal('124.62'))
# ('Lowrance Kleinmintz', 'Beigang', 'CN', Decimal('144.09'))
# ('Dore Coyett', 'Kota Bharu', 'MY', Decimal('101.60'))
# ('Baxy Dunkerley', 'Layu', 'CN', Decimal('93.13'))
# ('Godfrey Jellicorse', 'Vazhiny', 'RU', Decimal('91.84'))
# ('Ives Darmody', 'Jiangkou', 'CN', Decimal('133.17'))
# ('Hervey Ganning', 'Torres', 'BR', Decimal('83.99'))
# ('Bennett Pendered', 'Changnyeong', 'KR', Decimal('69.38'))
# ('Jilleen Foux', 'KhÄ\x81naqÄ\x81h', 'AF', Decimal('119.80'))
# ('Jefferson Lauderdale', 'Batanghari', 'ID', Decimal('125.00'))
# ('Stirling Santry', 'ChhÄ\x81galnÄ\x81iya', 'BD', Decimal('235.00'))
# ('Reilly Domonkos', 'Fonte Boa da Brincosa', 'PT', Decimal('75.00'))
# ('Mary Demangel', 'Daszewice', 'PL', Decimal('220.00'))
# ('Carolan Di Giacomo', 'Talin Hiag', 'CN', Decimal('320.00'))
# ('Clarette Barreau', 'Zhongtang', 'CN', Decimal('210.00'))
# ('Germaine Vallack', 'Voronezh', 'RU', Decimal('310.00'))
# ('Alena Geratasch', 'Augsburg', 'DE', Decimal('225.00'))
# ('Dill Beardshall', 'Daohe', 'CN', Decimal('190.00'))
# ('Dolorita Drayton', 'Sitrah', 'BH', Decimal('98.00'))
# ('Guthry Galpin', 'Forbach', 'FR', Decimal('168.27'))
# ('Paton Fritzer', 'Nowe Grocholice', 'PL', Decimal('124.62'))
# ('Kelbee Illesley', 'Sete Lagoas', 'BR', Decimal('144.09'))
# ('Christabella Coathup', 'Bangil', 'ID', Decimal('101.60'))
# ('Ephrem Steers', 'Saint-AndrÃ©-Avellin', 'CA', Decimal('93.13'))
